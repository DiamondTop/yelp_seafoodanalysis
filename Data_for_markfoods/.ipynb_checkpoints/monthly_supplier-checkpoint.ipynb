# %%
import pandas as pd
import numpy as np
import datetime


# File to Load (Remember to Change These)
file_to_load = "resources/Datamyne_toothfish_monthly_2020.csv"

# Read Purchasing File and store into Pandas data frame
#monthly_data = pd.read_csv(file_to_load)


monthly_data = pd.read_csv(file_to_load)

# %%
monthly_data
# Out:
#          Date Bill of lading Nbr.                   Consignee Declared  \
# 0   2/11/2020    SUDU59BUE026704X                   STAVIS SEAFOOD LLC
# 1   2/11/2020    SUDU59BUE026679X                   STAVIS SEAFOOD LLC
# 2   2/11/2020    SUDU59BUE026512X                           mark foods
# 3   2/10/2020        MEDUCH355884       SABANAMAR INTERNATIONAL L.L.C.
# 4   2/10/2020    SUDUB0SCL000225X                DEEP BLUE FISHERY LLC
# 5    2/6/2020    SUDU59BUE025610X                           mark foods
# 6    2/6/2020    SUDU59BUE025549X                           mark foods
# 7    2/6/2020    SUDU59BUE025341X                           mark foods
# 8    2/6/2020    SUDU59BUE025340X                           mark foods
# 9    2/6/2020    SUDU59BUE025339X                           mark foods
# 10   2/6/2020    SUDU59BUE025338X                           mark foods
# 11   2/6/2020    SUDU59BUE025337X                           mark foods
# ...

# %%
monthly_data['Date']
# Out:
# 0     2/11/2020
# 1     2/11/2020
# 2     2/11/2020
# 3     2/10/2020
# 4     2/10/2020
# 5      2/6/2020
# 6      2/6/2020
# 7      2/6/2020
# 8      2/6/2020
# 9      2/6/2020
# 10     2/6/2020
# 11     2/6/2020
# 12     2/6/2020
# 13     2/5/2020
# 14     2/5/2020
# 15     2/5/2020
# 16     2/5/2020
# 17    1/30/2020
# 18    1/30/2020
# 19    1/26/2020
# 20    1/25/2020
# 21    1/24/2020
# 22    1/24/2020
# 23    1/23/2020
# 24    1/22/2020
# 25    1/22/2020
# 26    1/16/2020
# 27    1/14/2020
# 28    1/14/2020
# 29    1/12/2020
# 30    1/11/2020
# 31    1/10/2020
# 32     1/8/2020
# 33     1/8/2020
# 34     1/6/2020
# 35     1/5/2020
# 36     1/5/2020
# 37     1/3/2020
# 38     1/3/2020
# 39     1/3/2020
# Name: Date, dtype: object

# %%
monthly_data_df = pd.DataFrame(monthly_data)
monthly_data_df
# Out:
#          Date Bill of lading Nbr.                   Consignee Declared  \
# 0   2/11/2020    SUDU59BUE026704X                   STAVIS SEAFOOD LLC
# 1   2/11/2020    SUDU59BUE026679X                   STAVIS SEAFOOD LLC
# 2   2/11/2020    SUDU59BUE026512X                           mark foods
# 3   2/10/2020        MEDUCH355884       SABANAMAR INTERNATIONAL L.L.C.
# 4   2/10/2020    SUDUB0SCL000225X                DEEP BLUE FISHERY LLC
# 5    2/6/2020    SUDU59BUE025610X                           mark foods
# 6    2/6/2020    SUDU59BUE025549X                           mark foods
# 7    2/6/2020    SUDU59BUE025341X                           mark foods
# 8    2/6/2020    SUDU59BUE025340X                           mark foods
# 9    2/6/2020    SUDU59BUE025339X                           mark foods
# 10   2/6/2020    SUDU59BUE025338X                           mark foods
# 11   2/6/2020    SUDU59BUE025337X                           mark foods
# ...

# %%
monthly_data_df["Date"].value_counts().reset_index()
# Out:
#         index  Date
# 0    2/6/2020     8
# 1    2/5/2020     4
# 2    1/3/2020     3
# 3   2/11/2020     3
# 4   1/14/2020     2
# 5    1/8/2020     2
# 6   1/24/2020     2
# 7   2/10/2020     2
# 8   1/30/2020     2
# 9    1/5/2020     2
# 10  1/22/2020     2
# 11  1/25/2020     1
# 12  1/16/2020     1
# 13  1/12/2020     1
# 14   1/6/2020     1
# 15  1/10/2020     1
# 16  1/11/2020     1
# 17  1/26/2020     1
# 18  1/23/2020     1

# %%
for col in monthly_data_df.columns: 
    print(col)
# Out:
# Date
# Bill of lading Nbr.
# Consignee Declared
# Shipper Declared
# Short Container Description
# Country of Origin
# Port of Arrival
# Final Destination
# Weight
# Weight Unit
# Quantity
# Quantity Unit
# Container
# Pieces
# Description
# Harmonized
# Marks & Numbers
# HS

# %%
date = pd.date_range('1/1/2020', '1/31/2020')
date
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10', '2020-01-11', '2020-01-12',
#                '2020-01-13', '2020-01-14', '2020-01-15', '2020-01-16',
#                '2020-01-17', '2020-01-18', '2020-01-19', '2020-01-20',
#                '2020-01-21', '2020-01-22', '2020-01-23', '2020-01-24',
#                '2020-01-25', '2020-01-26', '2020-01-27', '2020-01-28',
#                '2020-01-29', '2020-01-30', '2020-01-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
columns
# Out:
# ['Date', 'Shipper Declared', 'Country of Origin', 'Weight', 'Port of Arrival']

# %%
monthly_data_df['datetime'] = pd.to_datetime(monthly_data_df['Date'])
monthly_data_df['datetime']
# Out:
# 0    2020-02-11
# 1    2020-02-11
# 2    2020-02-11
# 3    2020-02-10
# 4    2020-02-10
# 5    2020-02-06
# 6    2020-02-06
# 7    2020-02-06
# 8    2020-02-06
# 9    2020-02-06
# 10   2020-02-06
# 11   2020-02-06
# 12   2020-02-06
# 13   2020-02-05
# 14   2020-02-05
# 15   2020-02-05
# 16   2020-02-05
# 17   2020-01-30
# 18   2020-01-30
# 19   2020-01-26
# 20   2020-01-25
# 21   2020-01-24
# 22   2020-01-24
# 23   2020-01-23
# 24   2020-01-22
# 25   2020-01-22
# 26   2020-01-16
# 27   2020-01-14
# 28   2020-01-14
# 29   2020-01-12
# 30   2020-01-11
# 31   2020-01-10
# 32   2020-01-08
# 33   2020-01-08
# 34   2020-01-06
# 35   2020-01-05
# 36   2020-01-05
# 37   2020-01-03
# 38   2020-01-03
# 39   2020-01-03
# Name: datetime, dtype: datetime64[ns]

# %%
date = pd.date_range('2020-01-01', '2020-01-31')
date
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10', '2020-01-11', '2020-01-12',
#                '2020-01-13', '2020-01-14', '2020-01-15', '2020-01-16',
#                '2020-01-17', '2020-01-18', '2020-01-19', '2020-01-20',
#                '2020-01-21', '2020-01-22', '2020-01-23', '2020-01-24',
#                '2020-01-25', '2020-01-26', '2020-01-27', '2020-01-28',
#                '2020-01-29', '2020-01-30', '2020-01-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
columns = ["Date", "Shipper Declared", "Country of Origin", "Weight", "Port of Arrival", "datetime"]
columns
# Out:
# ['Date',
#  'Shipper Declared',
#  'Country of Origin',
#  'Weight',
#  'Port of Arrival',
#  'datetime']

# %%
monthly_data_df, columns
# Out:
# (         Date Bill of lading Nbr.                   Consignee Declared  \
#  0   2/11/2020    SUDU59BUE026704X                   STAVIS SEAFOOD LLC
#  1   2/11/2020    SUDU59BUE026679X                   STAVIS SEAFOOD LLC
#  2   2/11/2020    SUDU59BUE026512X                           mark foods
#  3   2/10/2020        MEDUCH355884       SABANAMAR INTERNATIONAL L.L.C.
#  4   2/10/2020    SUDUB0SCL000225X                DEEP BLUE FISHERY LLC
#  5    2/6/2020    SUDU59BUE025610X                           mark foods
#  6    2/6/2020    SUDU59BUE025549X                           mark foods
#  7    2/6/2020    SUDU59BUE025341X                           mark foods
#  8    2/6/2020    SUDU59BUE025340X                           mark foods
#  9    2/6/2020    SUDU59BUE025339X                           mark foods
#  10   2/6/2020    SUDU59BUE025338X                           mark foods
#  11   2/6/2020    SUDU59BUE025337X                           mark foods
# ...

# %%
Jan_df = monthly_data_df.loc[monthly_data_df["datetime"] == date,  columns]
Jan_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-4e62b1da62ae> in <module>
# ----> 1 Jan_df = monthly_data_df.loc[monthly_data_df["datetime"] == date,  columns]
#       2 Jan_df
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#    1714
#    1715             res_values = dispatch_to_index_op(op, self, other,
# -> 1716                                               pd.DatetimeIndex)
#    1717
#    1718             return self._constructor(res_values, index=self.index,
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\ops.py in dispatch_to_index_op(op, left, right, index_class)
#    1189         left_idx = left_idx._shallow_copy(freq=None)
#    1190     try:
# -> 1191         result = op(left_idx, right)
#    1192     except NullFrequencyError:
# ...

# %%
monthly_data_df['Shipper Declared']

# %%
monthly_data_df['Shipper Declared']


monthly_data_df['Date']

# %%
monthly_data['New_Date'] = pd.to_datetime(monthly_data['Date'], format='%d/%m/%Y')

# %%
monthly_data["Shipper Declared"].unique()
total_players = monthly_data["Shipper Declared"].unique().shape[0]
total_players

# %%
player = pd.DataFrame({ "Total Players": [total_players]})
    
player

# %%
from datetime import datetime
datetime.strptime('07/28/2014', '%m/%d/%Y')

# %%
date = pd.date_range('1/1/2020', '1/31/2020')
date

# %%
price_male = monthly_data.loc[monthly_data["Date"] == '2020/3/1']
price_male

# %%
df['UK Date'] = pd.to_datetime(monthly_data['Date'], format='%m/%d/%y')

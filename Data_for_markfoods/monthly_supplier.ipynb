# %%
import pandas as pd
import numpy as np
import datetime


# File to Load (Remember to Change These)
file_to_load = "resources/Datamyne_toothfish_monthly_2020.csv"

# Read Purchasing File and store into Pandas data frame
#monthly_data = pd.read_csv(file_to_load)


monthly_data = pd.read_csv(file_to_load)

# %%
monthly_data
# Out:
#          Date Bill of lading Nbr.                   Consignee Declared  \
# 0   2/11/2020    SUDU59BUE026704X                   STAVIS SEAFOOD LLC
# 1   2/11/2020    SUDU59BUE026679X                   STAVIS SEAFOOD LLC
# 2   2/11/2020    SUDU59BUE026512X                           mark foods
# 3   2/10/2020        MEDUCH355884       SABANAMAR INTERNATIONAL L.L.C.
# 4   2/10/2020    SUDUB0SCL000225X                DEEP BLUE FISHERY LLC
# 5    2/6/2020    SUDU59BUE025610X                           mark foods
# 6    2/6/2020    SUDU59BUE025549X                           mark foods
# 7    2/6/2020    SUDU59BUE025341X                           mark foods
# 8    2/6/2020    SUDU59BUE025340X                           mark foods
# 9    2/6/2020    SUDU59BUE025339X                           mark foods
# 10   2/6/2020    SUDU59BUE025338X                           mark foods
# 11   2/6/2020    SUDU59BUE025337X                           mark foods
# ...

# %%
monthly_data['Date']
# Out:
# 0     2/11/2020
# 1     2/11/2020
# 2     2/11/2020
# 3     2/10/2020
# 4     2/10/2020
# 5      2/6/2020
# 6      2/6/2020
# 7      2/6/2020
# 8      2/6/2020
# 9      2/6/2020
# 10     2/6/2020
# 11     2/6/2020
# 12     2/6/2020
# 13     2/5/2020
# 14     2/5/2020
# 15     2/5/2020
# 16     2/5/2020
# 17    1/30/2020
# 18    1/30/2020
# 19    1/26/2020
# 20    1/25/2020
# 21    1/24/2020
# 22    1/24/2020
# 23    1/23/2020
# 24    1/22/2020
# 25    1/22/2020
# 26    1/16/2020
# 27    1/14/2020
# 28    1/14/2020
# 29    1/12/2020
# 30    1/11/2020
# 31    1/10/2020
# 32     1/8/2020
# 33     1/8/2020
# 34     1/6/2020
# 35     1/5/2020
# 36     1/5/2020
# 37     1/3/2020
# 38     1/3/2020
# 39     1/3/2020
# Name: Date, dtype: object

# %%
monthly_data_df = pd.DataFrame(monthly_data)
monthly_data_df
# Out:
#          Date Bill of lading Nbr.                   Consignee Declared  \
# 0   2/11/2020    SUDU59BUE026704X                   STAVIS SEAFOOD LLC
# 1   2/11/2020    SUDU59BUE026679X                   STAVIS SEAFOOD LLC
# 2   2/11/2020    SUDU59BUE026512X                           mark foods
# 3   2/10/2020        MEDUCH355884       SABANAMAR INTERNATIONAL L.L.C.
# 4   2/10/2020    SUDUB0SCL000225X                DEEP BLUE FISHERY LLC
# 5    2/6/2020    SUDU59BUE025610X                           mark foods
# 6    2/6/2020    SUDU59BUE025549X                           mark foods
# 7    2/6/2020    SUDU59BUE025341X                           mark foods
# 8    2/6/2020    SUDU59BUE025340X                           mark foods
# 9    2/6/2020    SUDU59BUE025339X                           mark foods
# 10   2/6/2020    SUDU59BUE025338X                           mark foods
# 11   2/6/2020    SUDU59BUE025337X                           mark foods
# ...

# %%
monthly_data_df["Date"].value_counts().reset_index()
# Out:
#         index  Date
# 0    2/6/2020     8
# 1    2/5/2020     4
# 2    1/3/2020     3
# 3   2/11/2020     3
# 4   1/30/2020     2
# 5    1/5/2020     2
# 6    1/8/2020     2
# 7   2/10/2020     2
# 8   1/24/2020     2
# 9   1/14/2020     2
# 10  1/22/2020     2
# 11  1/12/2020     1
# 12   1/6/2020     1
# 13  1/25/2020     1
# 14  1/23/2020     1
# 15  1/11/2020     1
# 16  1/10/2020     1
# 17  1/26/2020     1
# 18  1/16/2020     1

# %%
for col in monthly_data_df.columns: 
    print(col)
# Out:
# Date
# Bill of lading Nbr.
# Consignee Declared
# Shipper Declared
# Short Container Description
# Country of Origin
# Port of Arrival
# Final Destination
# Weight
# Weight Unit
# Quantity
# Quantity Unit
# Container
# Pieces
# Description
# Harmonized
# Marks & Numbers
# HS

# %%
date = pd.date_range('1/1/2020', '1/31/2020')
date
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10', '2020-01-11', '2020-01-12',
#                '2020-01-13', '2020-01-14', '2020-01-15', '2020-01-16',
#                '2020-01-17', '2020-01-18', '2020-01-19', '2020-01-20',
#                '2020-01-21', '2020-01-22', '2020-01-23', '2020-01-24',
#                '2020-01-25', '2020-01-26', '2020-01-27', '2020-01-28',
#                '2020-01-29', '2020-01-30', '2020-01-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
#Ensure df['date'] is a Series with dtype datetime64[ns]:

monthly_data_df['Date'] = pd.to_datetime(monthly_data_df['Date'])
monthly_data_df['Date']
# Out:
# 0    2020-02-11
# 1    2020-02-11
# 2    2020-02-11
# 3    2020-02-10
# 4    2020-02-10
# 5    2020-02-06
# 6    2020-02-06
# 7    2020-02-06
# 8    2020-02-06
# 9    2020-02-06
# 10   2020-02-06
# 11   2020-02-06
# 12   2020-02-06
# 13   2020-02-05
# 14   2020-02-05
# 15   2020-02-05
# 16   2020-02-05
# 17   2020-01-30
# 18   2020-01-30
# 19   2020-01-26
# 20   2020-01-25
# 21   2020-01-24
# 22   2020-01-24
# 23   2020-01-23
# 24   2020-01-22
# 25   2020-01-22
# 26   2020-01-16
# 27   2020-01-14
# 28   2020-01-14
# 29   2020-01-12
# 30   2020-01-11
# 31   2020-01-10
# 32   2020-01-08
# 33   2020-01-08
# 34   2020-01-06
# 35   2020-01-05
# 36   2020-01-05
# 37   2020-01-03
# 38   2020-01-03
# 39   2020-01-03
# Name: Date, dtype: datetime64[ns]

# %%
date = pd.date_range('2020-01-01', '2020-01-31')
date

# %%
# Out:
# (         Date Bill of lading Nbr.                   Consignee Declared  \
#  0   2/11/2020    SUDU59BUE026704X                   STAVIS SEAFOOD LLC
#  1   2/11/2020    SUDU59BUE026679X                   STAVIS SEAFOOD LLC
#  2   2/11/2020    SUDU59BUE026512X                           mark foods
#  3   2/10/2020        MEDUCH355884       SABANAMAR INTERNATIONAL L.L.C.
#  4   2/10/2020    SUDUB0SCL000225X                DEEP BLUE FISHERY LLC
#  5    2/6/2020    SUDU59BUE025610X                           mark foods
#  6    2/6/2020    SUDU59BUE025549X                           mark foods
#  7    2/6/2020    SUDU59BUE025341X                           mark foods
#  8    2/6/2020    SUDU59BUE025340X                           mark foods
#  9    2/6/2020    SUDU59BUE025339X                           mark foods
#  10   2/6/2020    SUDU59BUE025338X                           mark foods
#  11   2/6/2020    SUDU59BUE025337X                           mark foods
# ...

# %%
columns = ["Date", "Shipper Declared", "Country of Origin", "Weight", "Port of Arrival"]
columns
# Out:
# ['Date', 'Shipper Declared', 'Country of Origin', 'Weight', 'Port of Arrival']

# %%
Jan_df = monthly_data_df.loc[monthly_data_df["datetime"] == '2020/01/03',  columns]
Jan_df
# Out:
#          Date                Shipper Declared Country of Origin     Weight  \
# 37 2020-01-03  CONSOLIDATED FISHERIES LIMITED  FALKLAND ISLANDS  22,571.00
# 38 2020-01-03  CONSOLIDATED FISHERIES LIMITED  FALKLAND ISLANDS  19,613.00
# 39 2020-01-03                       ZUIDERDAM     UNITED STATES        636
#
#        Port of Arrival
# 37            MIAMI,FL
# 38            MIAMI,FL
# 39  PORT EVERGLADES,FL

# %%
Jan_df = pd.DataFrame({'Date': pd.date_range(start='2020-01-01', end='2020-01-31')})
Jan_df
# Out:
#          Date
# 0  2020-01-01
# 1  2020-01-02
# 2  2020-01-03
# 3  2020-01-04
# 4  2020-01-05
# 5  2020-01-06
# 6  2020-01-07
# 7  2020-01-08
# 8  2020-01-09
# 9  2020-01-10
# 10 2020-01-11
# 11 2020-01-12
# 12 2020-01-13
# 13 2020-01-14
# 14 2020-01-15
# 15 2020-01-16
# 16 2020-01-17
# 17 2020-01-18
# 18 2020-01-19
# 19 2020-01-20
# 20 2020-01-21
# 21 2020-01-22
# 22 2020-01-23
# 23 2020-01-24
# 24 2020-01-25
# 25 2020-01-26
# 26 2020-01-27
# 27 2020-01-28
# 28 2020-01-29
# 29 2020-01-30
# 30 2020-01-31

# %%
#df['date'] = pd.date_range('2000-1-1', periods=200, freq='D')
mask = (monthly_data_df['Date'] > '2020-01-01') & (monthly_data_df['Date'] <= '2020-01-31')
print(monthly_data_df.loc[mask])
# Out:
#          Date Bill of lading Nbr.                   Consignee Declared  \
# 17 2020-01-30        SMLU5950827A                TRISTAN INTERNATIONAL
# 18 2020-01-30       SEAUSLN283074             SLADE GORTON & CO., INC.
# 19 2020-01-26        MEDUPL102191                         NOT DECLARED
# 20 2020-01-25    SUDUB0365A4IQ0U8  TO THE ORDER OF BANK OF AMERICA,N.A
# 21 2020-01-24    SUDU59BUE023858X                         NOT DECLARED
# 22 2020-01-24        MEDUPT018058              KENDELL SEAFOOD IMPORTS
# 23 2020-01-23    SUDUB9SCL043399X                      KENDELL SEAFOOD
# 24 2020-01-22    SUDU59MVD008057X              KENDELL SEAFOOD IMPORTS
# 25 2020-01-22    SUDU59MVD008055X              KENDELL SEAFOOD IMPORTS
# 26 2020-01-16    SUDU59BUE025093X                         NOT DECLARED
# 27 2020-01-14     SUGBFKPSY196600              KENDELL SEAFOOD IMPORTS
# 28 2020-01-14     SUGBFKPSY196598              KENDELL SEAFOOD IMPORTS
# ...

# %%
monthly_data_df.loc[mask]
# Out:
#          Date Bill of lading Nbr.                   Consignee Declared  \
# 17 2020-01-30        SMLU5950827A                TRISTAN INTERNATIONAL
# 18 2020-01-30       SEAUSLN283074             SLADE GORTON & CO., INC.
# 19 2020-01-26        MEDUPL102191                         NOT DECLARED
# 20 2020-01-25    SUDUB0365A4IQ0U8  TO THE ORDER OF BANK OF AMERICA,N.A
# 21 2020-01-24    SUDU59BUE023858X                         NOT DECLARED
# 22 2020-01-24        MEDUPT018058              KENDELL SEAFOOD IMPORTS
# 23 2020-01-23    SUDUB9SCL043399X                      KENDELL SEAFOOD
# 24 2020-01-22    SUDU59MVD008057X              KENDELL SEAFOOD IMPORTS
# 25 2020-01-22    SUDU59MVD008055X              KENDELL SEAFOOD IMPORTS
# 26 2020-01-16    SUDU59BUE025093X                         NOT DECLARED
# 27 2020-01-14     SUGBFKPSY196600              KENDELL SEAFOOD IMPORTS
# 28 2020-01-14     SUGBFKPSY196598              KENDELL SEAFOOD IMPORTS
# ...

# %%
new_df = pd.DataFrame(monthly_data_df.loc[mask])

# %%
new_df.head(3)
# Out:
#          Date Bill of lading Nbr.        Consignee Declared  \
# 17 2020-01-30        SMLU5950827A     TRISTAN INTERNATIONAL
# 18 2020-01-30       SEAUSLN283074  SLADE GORTON & CO., INC.
# 19 2020-01-26        MEDUPL102191              NOT DECLARED
#
#       Shipper Declared                        Short Container Description  \
# 17      TRANSMARINA CA  BOXES FROZEN FISH SHIPPER PROVIDED HS CODE  03...
# 18  PROYECTA CORP S.A.  419 CARTONS: 12.254,09 KGS. CH ILEAN SEABASS H...
# 19        NOT DECLARED  FROZEN PATAGONIAN TOOTHFIS H HGT MSC CERTIFIE ...
#
#    Country of Origin     Port of Arrival Final Destination     Weight  \
# 17           ECUADOR            MIAMI,FL      NOT DECLARED  39,599.00
# 18             CHILE       LONG BEACH,CA      NOT DECLARED  29,343.00
# 19         MAURITIUS  PORT EVERGLADES,FL      NOT DECLARED  43,540.00
#
#    Weight Unit  Quantity Quantity Unit    Container Pieces  \
# 17           L  2,214.00           BOX  CTWU1601370  2,214
# ...

# %%
# Delete the duplicate 'Country Code' column and rename the first one back to 'Country Code'
#del new_df['Bill of lading Nbr.']
#del new_df['Final Destination']
new_df.head()
# Out:
#          Date                   Consignee Declared  \
# 17 2020-01-30                TRISTAN INTERNATIONAL
# 18 2020-01-30             SLADE GORTON & CO., INC.
# 19 2020-01-26                         NOT DECLARED
# 20 2020-01-25  TO THE ORDER OF BANK OF AMERICA,N.A
# 21 2020-01-24                         NOT DECLARED
#
#                   Shipper Declared  \
# 17                  TRANSMARINA CA
# 18              PROYECTA CORP S.A.
# 19                    NOT DECLARED
# 20  INVERSIONES PERU PACIFICO S.A.
# 21                    NOT DECLARED
#
#                           Short Container Description Country of Origin  \
# 17  BOXES FROZEN FISH SHIPPER PROVIDED HS CODE  03...           ECUADOR
# 18  419 CARTONS: 12.254,09 KGS. CH ILEAN SEABASS H...             CHILE
# 19  FROZEN PATAGONIAN TOOTHFIS H HGT MSC CERTIFIE ...         MAURITIUS
# 20  1405 BOXES WILD PINK PATAGONIANIQF HLSO 16/20 ...              PERU
# 21  PATAGONIAN TOOTHFISH(DISSOSTICHUS ELEGINOIDES)...         ARGENTINA
#
# ...

# %%
# Collect the mean unemployment rates for the world
average_supplier = new_df.sum()
average_supplier
# Out:
# Harmonized    152107.0
# dtype: float64

# %%
# Collect the years where data was collected
months = average_supplier.keys()

# Plot the world average as a line chart
supplier_avg, = plt.plot(months, average_supplier, color="blue", label="World Average" )

# Plot the unemployment values for a single country
#months, = plt.plot(months, average_supplier.loc['Shipper Declared',["01"], 
#                        color="green",label=months.loc['Shipper Declared',"months"])

# Create a legend for our chart
plt.legend(handles=[supplier_avg], loc="best")

# Show the chart
plt.show()

# %%
supplier_df = pd.DataFrame(new_df.groupby("Shipper Declared")["Date"].value_counts())
supplier_df.head(30)
# Out:
#                                               Date
# Shipper Declared                  Date
# CJ CAUTRE FOODS JOINT STOCK COMPA 2020-01-08     1
# CONSOLIDATED FISHERIES LIMITED    2020-01-03     2
# CONSOLIDATED FISHERIES LTD        2020-01-14     2
# HONGJIN CORPORATION               2020-01-22     2
# IMP.Y EXP. SAN ISIDRO S.A.        2020-01-06     1
#                                   2020-01-23     1
# INVERSIONES PERU PACIFICO S.A.    2020-01-25     1
# MARINE FOODS S.A                  2020-01-12     1
# NH TRADING CO., LTD.              2020-01-10     1
# NOT DECLARED                      2020-01-16     1
#                                   2020-01-24     1
#                                   2020-01-26     1
# PROYECTA CORP S.A.                2020-01-30     1
# ROD INTERNATIONAL                 2020-01-08     1
# SAPMER                            2020-01-24     1
# SEAFROST S.A.C.                   2020-01-11     1
# TRANSMARINA CA                    2020-01-30     1
# ...

# %%
import matplotlib.pyplot as plt


#plotting the scatter plot

plt.scatter(Shipper Declared, Dates, marker="o",s=Dates*8, alpha=0.75, facecolors="Coral", edgecolors="black", label='Shipper Declared')
plt.scatter(suburban_num_rides, suburban_fare, marker="o",s=suburban_driver_count*8, alpha=0.75, facecolors="SkyBlue", edgecolors="black", label='Suburban')
plt.scatter(rural_num_rides, rural_fare, marker="o",s=rural_driver_count*8, alpha=0.75, facecolors="Gold", edgecolors="black", label='Rural')


plt.legend(loc='upper right')
plt.grid()
plt.xlabel('num_rides')
plt.ylabel('avg_fare')
plt.title('Pyber Rideshare')
plt.figtext(0.814, 0.01, 'Circle size relative to driver_count', 
            horizontalalignment='right', fontsize=6) 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1860         try:
# -> 1861             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    1862             # If tzaware, these values represent unix timestamps, so we
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_converter.py in _convert_1d(values, unit, axis)
#     329             try:
# ...

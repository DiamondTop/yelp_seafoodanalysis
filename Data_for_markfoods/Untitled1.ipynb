# %%
# Import Dependencies
import pandas as pd
import json
import requests
from pprint import pprint
import numpy as np
import random
import matplotlib.pyplot as plt


# Import API key
from api_keys import api_key

# %%
headers = {'Authorization': 'Bearer %s' % api_key}

# %%
#search link on yelp
url='https://api.yelp.com/v3/businesses/search'

# %%
#running search through yelp and return the max results
data = []
count = 0
for offset in range(0, 999, 50):
        params = {
            'limit': 50, 
            'location':'New York',
            'term': 'seabass',
            'offset': offset
        }

        response = requests.get(url, headers=headers, params=params)
        if response.status_code == 200:
            data += response.json()['businesses']
            count = count + 1
        elif response.status_code == 400:
            print('400 Bad Request')
            break
data
# Out:
# [{'id': 'WJS06XxRdc6DD1s4LWE9HA',
#   'alias': 'fish-cheeks-new-york',
#   'name': 'Fish Cheeks',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pqupe3fe52869QQ23KkiBg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/fish-cheeks-new-york?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 628,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'raw_food', 'title': 'Live/Raw Food'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7258, 'longitude': -73.9927},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '55 Bond St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['55 Bond St', 'New York, NY 10012']},
# ...

# %%
counter = 0
for business in data:
    
    print(counter, "Name:", business["name"])
    print("Rating:", business["rating"])
    print("Category:", business["categories"])
    print("Address:", " ".join(business["location"]["display_address"]))
    print("Phone:", business["phone"])
    print("\n")
    counter = counter + 1
# Out:
# 0 Name: Fish Cheeks
# Rating: 4.5
# Category: [{'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'thai', 'title': 'Thai'}, {'alias': 'raw_food', 'title': 'Live/Raw Food'}]
# Address: 55 Bond St New York, NY 10012
# Phone: +12126772223
#
#
# 1 Name: Kotobuki Manhattan
# Rating: 4.0
# Category: [{'alias': 'japanese', 'title': 'Japanese'}, {'alias': 'sushi', 'title': 'Sushi Bars'}, {'alias': 'seafood', 'title': 'Seafood'}]
# Address: 56 3rd Ave New York, NY 10003
# Phone: +12123535088
#
#
# 2 Name: Extra Virgin
# Rating: 3.5
# Category: [{'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'greek', 'title': 'Greek'}, {'alias': 'italian', 'title': 'Italian'}]
# Address: 259 W 4th St New York, NY 10014
# Phone: +12126919359
#
#
# 3 Name: Au Za'atar
# Rating: 4.0
# Category: [{'alias': 'wine_bars', 'title': 'Wine Bars'}, {'alias': 'lebanese', 'title': 'Lebanese'}, {'alias': 'mediterranean', 'title': 'Mediterranean'}]
# Address: 188 Avenue A New York, NY 10009
# Phone: +12122545660
#
#
# ...

# %%
print(json.dumps(data, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "alias": "fish-cheeks-new-york",
#         "categories": [
#             {
#                 "alias": "seafood",
#                 "title": "Seafood"
#             },
#             {
#                 "alias": "thai",
#                 "title": "Thai"
#             },
#             {
#                 "alias": "raw_food",
#                 "title": "Live/Raw Food"
#             }
#         ],
#         "coordinates": {
#             "latitude": 40.7258,
#             "longitude": -73.9927
#         },
#         "display_phone": "(212) 677-2223",
#         "distance": 2258.7720584764224,
#         "id": "WJS06XxRdc6DD1s4LWE9HA",
#         "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/pqupe3fe52869QQ23KkiBg/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "55 Bond St",
#             "address2": "",
#             "address3": null,
#             "city": "New York",
#             "country": "US",
# ...

# %%
json.loads(response.text)
# Out:
# {'businesses': [{'id': 'TbZYmsdoHHWdBftbFG2lAA',
#    'alias': 'frankie-and-johnnies-steakhouse-rye',
#    'name': "Frankie & Johnnie's Steakhouse",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Y42r2rMFuO36tPsnrdlYYg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/frankie-and-johnnies-steakhouse-rye?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#    'review_count': 77,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.9845663, 'longitude': -73.68492},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$$',
#    'location': {'address1': '77 Purchase St',
#     'address2': '',
#     'address3': '',
#     'city': 'Rye',
#     'zip_code': '10580',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['77 Purchase St', 'Rye, NY 10580']},
#    'phone': '+19149253900',
# ...

# %%
data2 = response.json()

# %%
print(json.dumps(data2, indent=4, sort_keys=True))
# Out:
# {
#     "businesses": [
#         {
#             "alias": "frankie-and-johnnies-steakhouse-rye",
#             "categories": [
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 40.9845663,
#                 "longitude": -73.68492
#             },
#             "display_phone": "(914) 925-3900",
#             "distance": 40503.12654948761,
#             "id": "TbZYmsdoHHWdBftbFG2lAA",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/Y42r2rMFuO36tPsnrdlYYg/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "77 Purchase St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Rye",
#                 "country": "US",
#                 "display_address": [
#                     "77 Purchase St",
# ...

# %%
data2["businesses"][49]
# Out:
# {'id': '4OFUY9fen74A8UOHWD9LQA',
#  'alias': 'akai-lounge-englewood',
#  'name': 'Akai Lounge',
#  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xpM9Nu8ByLR2Sri21ZkunA/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/akai-lounge-englewood?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#  'review_count': 151,
#  'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#  'rating': 4.0,
#  'coordinates': {'latitude': 40.893970489502, 'longitude': -73.9738922119141},
#  'transactions': ['delivery'],
#  'price': '$$',
#  'location': {'address1': '11 N Dean St',
#   'address2': '',
#   'address3': '',
#   'city': 'Englewood',
#   'zip_code': '07631',
#   'country': 'US',
#   'state': 'NJ',
#   'display_address': ['11 N Dean St', 'Englewood, NJ 07631']},
#  'phone': '+12015410086',
#  'display_phone': '(201) 541-0086',
#  'distance': 21038.386787612573}

# %%
len(data2["businesses"])
# Out:
# 50

# %%
businesses2 = data2["businesses"]

# %%
counter = 0
for business in businesses2:
    counter = counter + 1
    print(counter, "Name:", business["name"])
    print("Rating:", business["rating"])
    print("Address:", " ".join(business["location"]["display_address"]))
    print("Phone:", business["phone"])
    print("\n")
# Out:
# 1 Name: Frankie & Johnnie's Steakhouse
# Rating: 3.5
# Address: 77 Purchase St Rye, NY 10580
# Phone: +19149253900
#
#
# 2 Name: Etcetera Etcetera
# Rating: 4.0
# Address: 352 W 44th St New York, NY 10036
# Phone: +12123994141
#
#
# 3 Name: Zen Fusion Cuisine
# Rating: 3.5
# Address: 79-28 Parsons Blvd Fresh Meadows, NY 11366
# Phone: +17185915555
#
#
# 4 Name: El Cid
# Rating: 3.5
# Address: 205 Paramus Rd Paramus, NJ 07652
# Phone: +12018430123
#
#
# 5 Name: Barbounia
# Rating: 3.5
# Address: 250 Park Ave S New York, NY 10003
# Phone: +12129950242
#
#
# 6 Name: Belle Gente
# Rating: 4.0
# Address: 644 Bloomfield Ave Verona, NJ 07044
# Phone: +19732394416
#
#
# 7 Name: Fuji Sushi
# Rating: 3.0
# Address: 238 W 56th St New York, NY 10019
# Phone: +12125869888
#
#
# 8 Name: The Greek on Main
# Rating: 4.0
# Address: 419 Main St Metuchen, NJ 08840
# Phone: +17325159457
#
#
# 9 Name: Niles NYC
# Rating: 3.5
# Address: 371 7th Ave New York, NY 10001
# Phone: +12126290210
#
#
# ...

# %%
id = business["id"]
 
url2 = "https://api.yelp.com/v3/businesses/" + "0CjK3esfpFcxIopebzjFxA" + "/reviews"
 
req = requests.get(url2, headers=headers)
 
parsed = json.loads(req.text)
 
reviews = parsed["reviews"]

 
print("--- Reviews ---")
 
for review in reviews:
        print("User:", review["user"]["name"], "Rating:", review["rating"], "Review:", review["text"], "\n")
# Out:
# --- Reviews ---
# User: Vivian C. Rating: 4 Review: 3.75/5
# One of my last stops before the quarantine. Good enough to get my Chinese fix before I'm locked in. Chinatown was already pretty quiet by the time I...
#
# User: Vanessa G. Rating: 5 Review: Best Chinese food!!!!! If you are looking for fresh, quality, food, and great service this is the place. This is the only restaurant I will eat Chinese food...
#
# User: Tanya R. Rating: 4 Review: Insta@dish_360
#
# The Good: We wanted the best soup dumplings and both Google and Yelp pointed us to Joe's Shanghai. We got the crab and pork meat soup...

# %%
parsed["reviews"]
# Out:
# [{'id': 'FglAF1z_G-pXyYzmokl8sA',
#   'url': 'https://www.yelp.com/biz/joes-shanghai-new-york-2?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&hrid=FglAF1z_G-pXyYzmokl8sA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'text': "3.75/5\nOne of my last stops before the quarantine. Good enough to get my Chinese fix before I'm locked in. Chinatown was already pretty quiet by the time I...",
#   'rating': 4,
#   'time_created': '2020-03-23 09:49:08',
#   'user': {'id': '3efMTDumo2gJwBQ-U_qVDw',
#    'profile_url': 'https://www.yelp.com/user_details?userid=3efMTDumo2gJwBQ-U_qVDw',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/_F2sj1gHOe0UPnxdYBRhpg/o.jpg',
#    'name': 'Vivian C.'}},
#  {'id': '1Uburt_Y1ZFSqBLN7GrJzw',
# ...

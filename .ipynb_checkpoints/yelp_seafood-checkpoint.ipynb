# %%
# Import Dependencies
import pandas as pd
import json
import requests
from pprint import pprint
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns

# Import API key
from api_keys import api_key

# %%
headers = {'Authorization': 'Bearer %s' % api_key}

# %%
#search link on yelp
url='https://api.yelp.com/v3/businesses/search'

# %%
#running search through yelp and return the max results
data = []
count = 0
for offset in range(0, 1000, 50):
        params = {
            'limit': 50, 
            'location':'New York',
            'term': 'seabass',
            'offset': offset
        }

        response = requests.get(url, headers=headers, params=params)
        if response.status_code == 200:
            data += response.json()['businesses']
            count = count + 1
        elif response.status_code == 400:
            print('400 Bad Request')
            break
data
# Out:
# [{'id': 'WJS06XxRdc6DD1s4LWE9HA',
#   'alias': 'fish-cheeks-new-york',
#   'name': 'Fish Cheeks',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pqupe3fe52869QQ23KkiBg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/fish-cheeks-new-york?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 651,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'raw_food', 'title': 'Live/Raw Food'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7258, 'longitude': -73.9927},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '55 Bond St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['55 Bond St', 'New York, NY 10012']},
#   'phone': '+12126772223',
#   'display_phone': '(212) 677-2223',
#   'distance': 2258.7720584764224},
#  {'id': 'HFn1sPqKSzvxaMk2n2ZtJw',
#   'alias': 'kotobuki-manhattan-new-york',
#   'name': 'Kotobuki Manhattan',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/lUQa7hPYeNnhb4qq7jI8fw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/kotobuki-manhattan-new-york?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 623,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.731107, 'longitude': -73.98912},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '56 3rd Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['56 3rd Ave', 'New York, NY 10003']},
#   'phone': '+12123535088',
#   'display_phone': '(212) 353-5088',
#   'distance': 2886.611027992669},
#  {'id': '0FaLilJs2VN83hOEBcBnPg',
#   'alias': 'au-zaatar-new-york',
#   'name': "Au Za'atar",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/F1qi52hOrfEPG-ayvT8bVw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/au-zaatar-new-york?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 873,
#   'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#    {'alias': 'lebanese', 'title': 'Lebanese'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.728901, 'longitude': -73.981185},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '188 Avenue A',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['188 Avenue A', 'New York, NY 10009']},
#   'phone': '+12122545660',
#   'display_phone': '(212) 254-5660',
#   'distance': 2832.5203005240082},
#  {'id': 'LYwNv8P1oBSuWqEYaw7Wbg',
#   'alias': 'midtown-catch-new-york',
#   'name': 'Midtown Catch',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KHBuRBgYDgIzGM9C4qWs4w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/midtown-catch-new-york?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 24,
#   'categories': [{'alias': 'seafoodmarkets', 'title': 'Seafood Markets'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7582645924672,
#    'longitude': -73.9624695495606},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '405 E 57th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10022',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['405 E 57th St', 'New York, NY 10022']},
#   'phone': '+16469187560',
#   'display_phone': '(646) 918-7560',
#   'distance': 6456.445759425975},
#  {'id': 'B3_K2kUVbYOU0VaLcj_LTw',
#   'alias': 'thai-villa-new-york-2',
#   'name': 'Thai Villa',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/OgCU9NPFIl8hF_04Zani9w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/thai-villa-new-york-2?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 3383,
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.73902, 'longitude': -73.99065},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '5 E 19th St',
#    'address2': 'G Floor',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['5 E 19th St', 'G Floor', 'New York, NY 10003']},
#   'phone': '+12128029999',
#   'display_phone': '(212) 802-9999',
#   'distance': 3744.570399827637},
#  {'id': 'ryvBsB9FrBBZDak87iGS1w',
#   'alias': 'the-seafire-grill-new-york-4',
#   'name': 'The Seafire Grill',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XfmiprKBLVpP5ukKd1GnrA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-seafire-grill-new-york-4?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 1279,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7547012104496, 'longitude': -73.972255513072},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '158 E 48th St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10017',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['158 E 48th St', 'New York, NY 10017']},
#   'phone': '+12129353785',
#   'display_phone': '(212) 935-3785',
#   'distance': 5783.28147646515},
#  {'id': 'KpBfFpjzsGvvqAzCasVW0g',
#   'alias': 'extra-virgin-new-york',
#   'name': 'Extra Virgin',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Idyk61NTgFmF2XYzdGyqxg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/extra-virgin-new-york?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 1253,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'greek', 'title': 'Greek'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.7353962496717,
#    'longitude': -74.0031888223197},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '259 W 4th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['259 W 4th St', 'New York, NY 10014']},
#   'phone': '+12126919359',
#   'display_phone': '(212) 691-9359',
#   'distance': 3413.7710556560824},
#  {'id': 'My17Ud2T_tXy_9ND9aezpQ',
#   'alias': 'blacksea-fish-and-grill-rego-park',
#   'name': 'BlackSea Fish & Grill',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bDKPNlYO5m1eFzWR_kZY0A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/blacksea-fish-and-grill-rego-park?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 346,
#   'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#    {'alias': 'turkish', 'title': 'Turkish'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7301, 'longitude': -73.863538},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$$',
#   'location': {'address1': '95-36 Queens Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Rego Park',
#    'zip_code': '11374',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['95-36 Queens Blvd', 'Rego Park, NY 11374']},
#   'phone': '+17182757555',
#   'display_phone': '(718) 275-7555',
#   'distance': 11355.70074214254},
#  {'id': 'tCoC4QReUsoZKZvc1Ni5DA',
#   'alias': 'seabra-marisqueira-newark',
#   'name': 'Seabra Marisqueira',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qnUZ43TicJhYmXbYD861Kw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/seabra-marisqueira-newark?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 527,
#   'categories': [{'alias': 'portuguese', 'title': 'Portuguese'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.72991, 'longitude': -74.16067},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '87 Madison St',
#    'address2': '',
#    'address3': '',
#    'city': 'Newark',
#    'zip_code': '07105',
#    'country': 'US',
#    'state': 'NJ',
#    'display_address': ['87 Madison St', 'Newark, NJ 07105']},
#   'phone': '+19734651250',
#   'display_phone': '(973) 465-1250',
#   'distance': 14283.696376996722},
#  {'id': 'A_GbgtUSyGWpihHZOqMdwQ',
#   'alias': 'little-basil-new-york-5',
#   'name': 'Little Basil',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Ojn2dqxqJlXoXtV3p2MsEg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/little-basil-new-york-5?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 498,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.741014, 'longitude': -73.982259},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '153 E 26th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10010',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['153 E 26th St', 'New York, NY 10010']},
#   'phone': '+12126891444',
#   'display_phone': '(212) 689-1444',
#   'distance': 4083.052133823934},
#  {'id': 'apykLG7DTZ-7xnOcZGDZZA',
#   'alias': 'taverna-kyclades-east-village-new-york-2',
#   'name': 'Taverna Kyclades - East Village',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ixZmWKWuEsXVl0eHwll21A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/taverna-kyclades-east-village-new-york-2?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 828,
#   'categories': [{'alias': 'greek', 'title': 'Greek'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7310782469639,
#    'longitude': -73.9825163036585},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '228 1st Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['228 1st Ave', 'New York, NY 10009']},
#   'phone': '+12124320011',
#   'display_phone': '(212) 432-0011',
#   'distance': 3018.164391413235},
#  {'id': '7OMGEtFWT6sdd9TVuoGqJQ',
#   'alias': 'okonomi-brooklyn',
#   'name': 'Okonomi',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RMSBnhoB5aHc-3CUSwULgg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/okonomi-brooklyn?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 457,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.712622, 'longitude': -73.9487843},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '150 Ainslie St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['150 Ainslie St', 'Brooklyn, NY 11211']},
#   'phone': '+19292950480',
#   'display_phone': '(929) 295-0480',
#   'distance': 3918.0469578683437},
#  {'id': 'DRitJoNGTkHXZvH_YpLIAw',
#   'alias': 'marc-forgione-new-york-2',
#   'name': 'Marc Forgione',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kthTZcWAduNfszGKCuRogA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/marc-forgione-new-york-2?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 924,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.71647, 'longitude': -74.0095599},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$$',
#   'location': {'address1': '134 Reade St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['134 Reade St', 'New York, NY 10013']},
#   'phone': '+12129419401',
#   'display_phone': '(212) 941-9401',
#   'distance': 1781.746273856987},
#  {'id': 'TCJrcryBkI6eg2HYThoiKg',
#   'alias': 'petite-crevette-brooklyn',
#   'name': 'Petite Crevette',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HhnCUa1fzQ2o4c4c9rnGHg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/petite-crevette-brooklyn?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 318,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'french', 'title': 'French'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.68396, 'longitude': -74.0018},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '144 Union St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11231',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['144 Union St', 'Brooklyn, NY 11231']},
#   'phone': '+17188552632',
#   'display_phone': '(718) 855-2632',
#   'distance': 2477.863579971962},
#  {'id': 'efYELOeAJ-CjKpzayEfblg',
#   'alias': 'cornerstone-cafe-new-york',
#   'name': 'Cornerstone Cafe',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/U83WNl9o1Q-YGf2HAE5yTA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/cornerstone-cafe-new-york?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 1116,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7220618263077, 'longitude': -73.983249573445},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '17 Ave B',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['17 Ave B', 'New York, NY 10009']},
#   'phone': '+12122281260',
#   'display_phone': '(212) 228-1260',
#   'distance': 2068.9234840255403},
#  {'id': 'wwYJlPAg4_DV_DihANcuOw',
#   'alias': 'estuary-new-york',
#   'name': 'Estuary',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nw7Jz-VNpdCbtsk9wF0shw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/estuary-new-york?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 25,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.6932355, 'longitude': -74.0007940774},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '159 Bridge Park Dr',
#    'address2': '',
#    'address3': 'Brooklyn Bridge Park',
#    'city': 'New York',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['159 Bridge Park Dr',
#     'Brooklyn Bridge Park',
#     'New York, NY 11201']},
#   'phone': '+17185216744',
#   'display_phone': '(718) 521-6744',
#   'distance': 1464.057918260259},
#  {'id': 'E9NMNWvV70HV5gB369N0EA',
#   'alias': 'nerai-new-york',
#   'name': 'Nerai',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TUc_jX0d2-nF1Qwx9IBcfA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/nerai-new-york?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 476,
#   'categories': [{'alias': 'greek', 'title': 'Greek'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.760258, 'longitude': -73.9730857},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$$',
#   'location': {'address1': '55 E 54th St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10022',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['55 E 54th St', 'New York, NY 10022']},
#   'phone': '+12127595554',
#   'display_phone': '(212) 759-5554',
#   'distance': 6351.483248101496},
#  {'id': 'lzS4xZdl9Yk1ULtbzi9ejQ',
#   'alias': 'hamido-seafood-astoria',
#   'name': 'Hamido Seafood',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4oqgcPx2IyQW-ZdcQaUj_Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hamido-seafood-astoria?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 136,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7750008, 'longitude': -73.9095623},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '3308 Ditmars Blvd',
#    'address2': None,
#    'address3': '',
#    'city': 'Astoria',
#    'zip_code': '11105',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['3308 Ditmars Blvd', 'Astoria, NY 11105']},
#   'phone': '+17185452200',
#   'display_phone': '(718) 545-2200',
#   'distance': 10525.096357777624},
#  {'id': 'DIqsYe-HJS8etyDyXNovBg',
#   'alias': 'seamores-new-york-14',
#   'name': 'Seamores',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ZRhyrPR5-4w_7ZaSLemDeg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/seamores-new-york-14?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 713,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.72074, 'longitude': -73.99696},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '390 Broome St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['390 Broome St', 'New York, NY 10013']},
#   'phone': '+12127306005',
#   'display_phone': '(212) 730-6005',
#   'distance': 1710.22686527899},
#  {'id': 'FZh1ZBFrb46tkRdZuMA7hQ',
#   'alias': 'troquet-new-york-3',
#   'name': 'Troquet',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MGBlb88rJ8jUrPJ4MH-0ng/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/troquet-new-york-3?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 165,
#   'categories': [{'alias': 'french', 'title': 'French'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7200024863923,
#    'longitude': -73.9990466250079},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '155 Grand St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['155 Grand St', 'New York, NY 10013']},
#   'phone': '+12123434295',
#   'display_phone': '(212) 343-4295',
#   'distance': 1667.5744502431774},
#  {'id': 'fJhzNx7t2QybrYudxULGoA',
#   'alias': 'marias-mediterranean-bayside',
#   'name': "Maria's Mediterranean",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/546cW1ju1k5S2SF39c9DDQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/marias-mediterranean-bayside?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 363,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'greek', 'title': 'Greek'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7661182, 'longitude': -73.7721149},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '38-11 Bell Blvd',
#    'address2': None,
#    'address3': '',
#    'city': 'Bayside',
#    'zip_code': '11361',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['38-11 Bell Blvd', 'Bayside, NY 11361']},
#   'phone': '+17182791606',
#   'display_phone': '(718) 279-1606',
#   'distance': 19893.259249075116},
#  {'id': 'NqYET0OyJKGfm9dJG8iDcg',
#   'alias': 'piccola-cucina-enoteca-new-york-2',
#   'name': 'Piccola Cucina Enoteca',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ZLkNhfn3Mr-ErBxGnXWewg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/piccola-cucina-enoteca-new-york-2?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 297,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.726284, 'longitude': -74.002151},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '184 Prince St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['184 Prince St', 'New York, NY 10012']},
#   'phone': '+12126253200',
#   'display_phone': '(212) 625-3200',
#   'distance': 2411.239960543615},
#  {'id': 'PGpCaNkB1meojnbgRmb2gQ',
#   'alias': 'buena-vista-restaurant-and-bar-new-york',
#   'name': 'Buena Vista Restaurant & Bar',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/cpPCEqAx6O_ytHY1ovajeA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/buena-vista-restaurant-and-bar-new-york?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 188,
#   'categories': [{'alias': 'latin', 'title': 'Latin American'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.75686, 'longitude': -73.99356},
#   'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '536 9th Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10018',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['536 9th Ave', 'New York, NY 10018']},
#   'phone': '+12123885040',
#   'display_phone': '(212) 388-5040',
#   'distance': 5715.3799368850405},
#  {'id': 'LOeDR4X-YRToeo3hy_plew',
#   'alias': 'the-fulton-new-york-2',
#   'name': 'The Fulton',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GFOoINd9z9q3CDQ3npDXkg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-fulton-new-york-2?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 174,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.7053694327276,
#    'longitude': -74.0010633899353},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '89 South St',
#    'address2': 'Pier 17',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10038',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['89 South St', 'Pier 17', 'New York, NY 10038']},
#   'phone': '+12128381200',
#   'display_phone': '(212) 838-1200',
#   'distance': 570.7452805978547},
#  {'id': '0ePn6TQSJQky4ueKeGQvpQ',
#   'alias': 'sugarfish-by-sushi-nozawa-new-york',
#   'name': 'SUGARFISH by sushi nozawa',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9_5GX7p80Z3lWqMleoY1EQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sugarfish-by-sushi-nozawa-new-york?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 831,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.73901, 'longitude': -73.98882},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '33 E 20th St',
#    'address2': None,
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['33 E 20th St', 'New York, NY 10003']},
#   'phone': '+13477058100',
#   'display_phone': '(347) 705-8100',
#   'distance': 3763.481038786802},
#  {'id': 'S9QZOR4UwfvYPPcHWfmNTw',
#   'alias': 'tellys-taverna-astoria',
#   'name': "Telly's Taverna",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1jCnos4LdG_A1NkkWwAoRw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tellys-taverna-astoria?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 343,
#   'categories': [{'alias': 'greek', 'title': 'Greek'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.775355401246, 'longitude': -73.9140461748688},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '28-13 23rd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Astoria',
#    'zip_code': '11105',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['28-13 23rd Ave', 'Astoria, NY 11105']},
#   'phone': '+17187289056',
#   'display_phone': '(718) 728-9056',
#   'distance': 10302.339745645035},
#  {'id': '2LcsDUTlvovnFz-SEcSJTQ',
#   'alias': 'astoria-seafood-long-island-city',
#   'name': 'Astoria Seafood',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1JpV37tvXerudsIowCpMMA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/astoria-seafood-long-island-city?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 700,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'greek', 'title': 'Greek'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.754, 'longitude': -73.9298699},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '37-10 33rd St',
#    'address2': '',
#    'address3': '',
#    'city': 'Long Island City',
#    'zip_code': '11101',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['37-10 33rd St', 'Long Island City, NY 11101']},
#   'phone': '+17183922680',
#   'display_phone': '(718) 392-2680',
#   'distance': 7657.624763799523},
#  {'id': '4WDHrSodF1Xidv9ezS6Sgg',
#   'alias': 'tuscany-steakhouse-new-york',
#   'name': 'Tuscany Steakhouse',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-ntrLHjqTqc7-M-7YNsOoQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tuscany-steakhouse-new-york?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 131,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.76546, 'longitude': -73.97724},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '117 West 58 St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10019',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['117 West 58 St', 'New York, NY 10019']},
#   'phone': '+12127578630',
#   'display_phone': '(212) 757-8630',
#   'distance': 6822.9638620456635},
#  {'id': 't7J_r2FQyuRMevzVycevpA',
#   'alias': 'silver-star-new-york',
#   'name': 'Silver Star',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/q-YgHFyDg0CkzJFoR0m7hg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/silver-star-new-york?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 137,
#   'categories': [{'alias': 'diners', 'title': 'Diners'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 40.76417, 'longitude': -73.9615199},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1236 2nd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10021',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1236 2nd Ave', 'New York, NY 10021']},
#   'phone': '+12122494250',
#   'display_phone': '(212) 249-4250',
#   'distance': 7071.777369652871},
#  {'id': 'Njr_f1J5Pve35OyPdBljVA',
#   'alias': 'convivium-osteria-brooklyn',
#   'name': 'Convivium Osteria',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/RIIMXKFc36OIwIhsXxnt2g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/convivium-osteria-brooklyn?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 481,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'},
#    {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.68105, 'longitude': -73.97748},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$$',
#   'location': {'address1': '68 5th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11217',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['68 5th Ave', 'Brooklyn, NY 11217']},
#   'phone': '+17188571833',
#   'display_phone': '(718) 857-1833',
#   'distance': 3058.002955250913},
#  {'id': 'GjEE8vvjqb7eeHA3BGNxAw',
#   'alias': 'barolo-east-new-york',
#   'name': 'Barolo East',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/msKukDHgkfhgy-hsuKrA7A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/barolo-east-new-york?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 121,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.75481, 'longitude': -73.97059},
#   'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#   'location': {'address1': '214 E 49th St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10017',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['214 E 49th St', 'New York, NY 10017']},
#   'phone': '+12127545710',
#   'display_phone': '(212) 754-5710',
#   'distance': 5833.791567148375},
#  {'id': 'WNF_VEyAkld2E1xGvSb2sw',
#   'alias': 'gupji-flushing',
#   'name': 'GUPJI',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/I1-_zoXcduUOSeKUBwEJIQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/gupji-flushing?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 91,
#   'categories': [{'alias': 'korean', 'title': 'Korean'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.75945, 'longitude': -73.82558},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '149-11A 41st Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Flushing',
#    'zip_code': '11355',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['149-11A 41st Ave', 'Flushing, NY 11355']},
#   'phone': '+19293290628',
#   'display_phone': '(929) 329-0628',
#   'distance': 16341.459634916886},
#  {'id': 'nhphKYpLl-pgRrEgZ1Kl2g',
#   'alias': 'brunos-bakery-and-resturant-staten-island',
#   'name': "Bruno's Bakery & Resturant",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/u90l9dDklcaTjooPrPg1Lg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/brunos-bakery-and-resturant-staten-island?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 198,
#   'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.6294899, 'longitude': -74.11164},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '676 Forest Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Staten Island',
#    'zip_code': '10310',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['676 Forest Ave', 'Staten Island, NY 10310']},
#   'phone': '+17184480993',
#   'display_phone': '(718) 448-0993',
#   'distance': 13017.885771471794},
#  {'id': 'KQ3b0rxCBnwKF0AHWjcJpg',
#   'alias': 'amylos-taverna-astoria',
#   'name': 'Amylos Taverna',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JhaRhaTbTdQypo8F0aNGPQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/amylos-taverna-astoria?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 177,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'greek', 'title': 'Greek'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.761003859362, 'longitude': -73.9229999999999},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '33-19 Broadway',
#    'address2': '',
#    'address3': None,
#    'city': 'Astoria',
#    'zip_code': '11106',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['33-19 Broadway', 'Astoria, NY 11106']},
#   'phone': '+17182150228',
#   'display_phone': '(718) 215-0228',
#   'distance': 8616.89488519687},
#  {'id': 'kmcgUxWhwlbmC-FAMTEF2g',
#   'alias': 'café-d-alsace-new-york-2',
#   'name': "Café D'Alsace",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VR3Zlw9vTGVKwyLlYR7dQw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/caf%C3%A9-d-alsace-new-york-2?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 1202,
#   'categories': [{'alias': 'french', 'title': 'French'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'cafes', 'title': 'Cafes'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.77916, 'longitude': -73.95104},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1695 2nd Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10128',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1695 2nd Ave', 'New York, NY 10128']},
#   'phone': '+12127225133',
#   'display_phone': '(212) 722-5133',
#   'distance': 8969.946647972984},
#  {'id': 'zyyT2yiyxxamC-jKc0v-fg',
#   'alias': 'omars-kitchen-and-rum-bar-new-york',
#   'name': "Omar's Kitchen and Rum Bar",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3wyLFJ6QbIFnfoH91PTx5g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/omars-kitchen-and-rum-bar-new-york?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 53,
#   'categories': [{'alias': 'caribbean', 'title': 'Caribbean'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.720422, 'longitude': -73.984525},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '29A Clinton St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['29A Clinton St', 'New York, NY 10002']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 1853.6675055102005},
#  {'id': 'ZpifrJsBsz7RUT1_Tyu9nQ',
#   'alias': 'hot-space-brooklyn',
#   'name': 'Hot Space',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0vGb1DMcHANg3X8wzv8zMA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hot-space-brooklyn?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 132,
#   'categories': [{'alias': 'szechuan', 'title': 'Szechuan'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.64068, 'longitude': -74.00476},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '774 51st St',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11220',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['774 51st St', 'Brooklyn, NY 11220']},
#   'phone': '+17189808801',
#   'display_phone': '(718) 980-8801',
#   'distance': 7257.711261458901},
#  {'id': '8ZedF0hYAvys8tb7ZtHGtQ',
#   'alias': 'lulu-lounge-and-bistro-edgewater-3',
#   'name': 'Lulu Lounge & Bistro',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tdkqaD2K1HFUBGCdYRqq8w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lulu-lounge-and-bistro-edgewater-3?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 10,
#   'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#    {'alias': 'mideastern', 'title': 'Middle Eastern'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.812386, 'longitude': -73.988309},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '360 Old RIver Rd',
#    'address2': None,
#    'address3': '',
#    'city': 'Edgewater',
#    'zip_code': '07020',
#    'country': 'US',
#    'state': 'NJ',
#    'display_address': ['360 Old RIver Rd', 'Edgewater, NJ 07020']},
#   'phone': '+12013473571',
#   'display_phone': '(201) 347-3571',
#   'distance': 11908.763879356831},
#  {'id': 'itblJyiTY2h2ACidLk66oA',
#   'alias': 'takahachi-new-york',
#   'name': 'Takahachi',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hEeWHgKSHySg1i9RUQTzUw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/takahachi-new-york?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 562,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.725315, 'longitude': -73.984436},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '85 Ave A',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['85 Ave A', 'New York, NY 10009']},
#   'phone': '+12125056524',
#   'display_phone': '(212) 505-6524',
#   'distance': 2353.3280141568616},
#  {'id': 't-UTPqMlFI36XIvNPBVdEQ',
#   'alias': 'baci-ristorante-brooklyn',
#   'name': 'Baci Ristorante',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/J5EfqebTM7hnKNUGny8ICA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/baci-ristorante-brooklyn?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 106,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.62452, 'longitude': -74.03091},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '8424 3rd Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11209',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['8424 3rd Ave', 'Brooklyn, NY 11209']},
#   'phone': '+17183335879',
#   'display_phone': '(718) 333-5879',
#   'distance': 9515.123974907727},
#  {'id': 'ONQRhDuWv0e9R5xOiI7YAA',
#   'alias': 'gyu-kaku-japanese-bbq-new-york-3',
#   'name': 'Gyu-Kaku Japanese BBQ',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GFV5hg5I2ioOuRPnKNAtsQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/gyu-kaku-japanese-bbq-new-york-3?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 1235,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'bbq', 'title': 'Barbeque'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.75908, 'longitude': -73.98989},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '321 W 44th St',
#    'address2': 'Unit 103',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10036',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['321 W 44th St', 'Unit 103', 'New York, NY 10036']},
#   'phone': '+16466929115',
#   'display_phone': '(646) 692-9115',
#   'distance': 5987.473305453897},
#  {'id': '4KzqwQus39gXgrwrDXAjWA',
#   'alias': 'eléa-new-york',
#   'name': 'Eléa',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cFF7gz4D1OQn-kdWh6qZdQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/el%C3%A9a-new-york?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 95,
#   'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#    {'alias': 'greek', 'title': 'Greek'},
#    {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.78754, 'longitude': -73.9765199},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '217 W 85th St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10024',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['217 W 85th St', 'New York, NY 10024']},
#   'phone': '+12123699800',
#   'display_phone': '(212) 369-9800',
#   'distance': 9255.428335342775},
#  {'id': 'OmCJH9XPC_Zc9S7CWe__Xw',
#   'alias': 'hot-space-grilled-fish-flushing-2',
#   'name': 'Hot Space Grilled Fish',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4v-Z4R-H4Wq9wwm3LlUR8g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hot-space-grilled-fish-flushing-2?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 114,
#   'categories': [{'alias': 'szechuan', 'title': 'Szechuan'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.759759546171, 'longitude': -73.8326680277916},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '39-07 Prince St',
#    'address2': 'Fl 1',
#    'address3': None,
#    'city': 'Flushing',
#    'zip_code': '11354',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['39-07 Prince St', 'Fl 1', 'Flushing, NY 11354']},
#   'phone': '+17189393237',
#   'display_phone': '(718) 939-3237',
#   'distance': 14897.556796755578},
#  {'id': '-Fv6St_t9ScaH2088owNRQ',
#   'alias': 'kings-carriage-house-new-york',
#   'name': "Kings' Carriage House",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GsB09Dbu2KEfTCEFISwokw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/kings-carriage-house-new-york?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 207,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'tea', 'title': 'Tea Rooms'},
#    {'alias': 'desserts', 'title': 'Desserts'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7754843, 'longitude': -73.9537374},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '251 E 82nd St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10028',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['251 E 82nd St', 'New York, NY 10028']},
#   'phone': '+12127345490',
#   'display_phone': '(212) 734-5490',
#   'distance': 8510.255481529244},
#  {'id': 'LpVbI-E9C-CSp7WhU5h2Iw',
#   'alias': 'fishmarket-restaurant-new-york',
#   'name': 'Fishmarket Restaurant',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BxY50B6ntFYQa8COuI1Fog/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/fishmarket-restaurant-new-york?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 548,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.70717, 'longitude': -74.00192},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '111 South St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10038',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['111 South St', 'New York, NY 10038']},
#   'phone': '+19173638101',
#   'display_phone': '(917) 363-8101',
#   'distance': 671.0784555500173},
#  {'id': 'uq5rHbGtBFwCwPkokIkKvQ',
#   'alias': 'jojo-new-york-3',
#   'name': 'JoJo',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tzYjNDXmSZVorVfwfN25gw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/jojo-new-york-3?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 155,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.76506, 'longitude': -73.96571},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$$',
#   'location': {'address1': '160 E 64th St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10065',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['160 E 64th St', 'New York, NY 10065']},
#   'phone': '+12122235656',
#   'display_phone': '(212) 223-5656',
#   'distance': 7054.833766162339},
#  {'id': 'qf9ONR0LAAFZ8fLDRkVHww',
#   'alias': 'mori-brooklyn',
#   'name': 'Mori',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HmH3WOR-urqFJX65kgDJ8g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mori-brooklyn?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 128,
#   'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'french', 'title': 'French'},
#    {'alias': 'izakaya', 'title': 'Izakaya'}],
#   'rating': 4.5,
# ...
#   'review_count': 121,
#   'categories': [{'alias': 'venues', 'title': 'Venues & Event Spaces'},
#    {'alias': 'wedding_planning', 'title': 'Wedding Planning'},
#    {'alias': 'catering', 'title': 'Caterers'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7457322, 'longitude': -73.6030517},
#   'transactions': [],
#   'location': {'address1': '440 Old Country Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Carle Place',
#    'zip_code': '11514',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['440 Old Country Rd', 'Carle Place, NY 11514']},
#   'phone': '+15163346125',
#   'display_phone': '(516) 334-6125',
#   'distance': 33272.14544833187},
#  {'id': 'e0jzp6je4Mm-NS21WuYKkg',
#   'alias': 'laurel-diner-long-beach',
#   'name': 'Laurel Diner',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9sJJeJ4XXMSecFT6Axjd5w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/laurel-diner-long-beach?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 193,
#   'categories': [{'alias': 'diners', 'title': 'Diners'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.5881751, 'longitude': -73.672968},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '300 W Park Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Long Beach',
#    'zip_code': '11561',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['300 W Park Ave', 'Long Beach, NY 11561']},
#   'phone': '+15164327728',
#   'display_phone': '(516) 432-7728',
#   'distance': 30093.111424021037},
#  {'id': 'XcRd6NSjyw6hJ6--k9SPlQ',
#   'alias': 'basilico-millburn-2',
#   'name': 'Basilico',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/A3pyb-b_q47rbIRaYGGxHA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/basilico-millburn-2?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 180,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.72388, 'longitude': -74.30606},
#   'transactions': ['pickup'],
#   'price': '$$$',
#   'location': {'address1': '324 Millburn Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Millburn',
#    'zip_code': '07041',
#    'country': 'US',
#    'state': 'NJ',
#    'display_address': ['324 Millburn Ave', 'Millburn, NJ 07041']},
#   'phone': '+19733797020',
#   'display_phone': '(973) 379-7020',
#   'distance': 26368.48902162722},
#  {'id': 'Ucxhqn56VtC-eYjdNsg7Og',
#   'alias': 'vitae-new-york',
#   'name': 'Vitae',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PD5FZ8csi4Wq4VU7fky6Nw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/vitae-new-york?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 775,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'},
#    {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7555884, 'longitude': -73.9785483},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$$',
#   'location': {'address1': '4 E 46th St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10017',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['4 E 46th St', 'New York, NY 10017']},
#   'phone': '+12126823562',
#   'display_phone': '(212) 682-3562',
#   'distance': 5731.366530356706},
#  {'id': 'i_q57YjbX1ZZkV4fP1KloQ',
#   'alias': 'daruma-japanese-restaurant-englewood',
#   'name': 'Daruma Japanese Restaurant',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/p8ydxHBwPYSvhWU88vum-Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/daruma-japanese-restaurant-englewood?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 114,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.8951568603516,
#    'longitude': -73.9731292724609},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '45 N Dean St',
#    'address2': '',
#    'address3': '',
#    'city': 'Englewood',
#    'zip_code': '07631',
#    'country': 'US',
#    'state': 'NJ',
#    'display_address': ['45 N Dean St', 'Englewood, NJ 07631']},
#   'phone': '+12015679600',
#   'display_phone': '(201) 567-9600',
#   'distance': 21177.388877143476},
#  {'id': 'lF0HXz7jRPftaWu_j0zYOQ',
#   'alias': 'the-garret-new-york-2',
#   'name': 'The Garret',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/E0uEzKOxXKBWAhGapDYi0w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-garret-new-york-2?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 89,
#   'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.729446, 'longitude': -73.980697},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '206 Ave A',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['206 Ave A', 'New York, NY 10009']},
#   'phone': '+12122286231',
#   'display_phone': '(212) 228-6231',
#   'distance': 2904.8163205274923},
#  {'id': 'GBWMJJ4_rDWqiXJ7AvHAOg',
#   'alias': '15-east-restaurant-new-york',
#   'name': '15 East Restaurant',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rktimrgpd3ccnmCY5tnmkA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/15-east-restaurant-new-york?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 633,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7363799, 'longitude': -73.99213},
#   'transactions': [],
#   'price': '$$$$',
#   'location': {'address1': '15 E 15th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['15 E 15th St', 'New York, NY 10003']},
#   'phone': '+12126470015',
#   'display_phone': '(212) 647-0015',
#   'distance': 3451.0300514061055},
#  {'id': 'SrdgagoG7fznuNbXkI87Vw',
#   'alias': 'american-sportfishing-charters-port-washington-2',
#   'name': 'American Sportfishing Charters',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jL4ITkY0S_Gqf9SULs3HVg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/american-sportfishing-charters-port-washington-2?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 3,
#   'categories': [{'alias': 'fishing', 'title': 'Fishing'},
#    {'alias': 'boatcharters', 'title': 'Boat Charters'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.8273195113456,
#    'longitude': -73.6976623535156},
#   'transactions': [],
#   'location': {'address1': '10 Matinicock',
#    'address2': None,
#    'address3': '',
#    'city': 'Port Washington',
#    'zip_code': '11050',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['10 Matinicock', 'Port Washington, NY 11050']},
#   'phone': '+15164578715',
#   'display_phone': '(516) 457-8715',
#   'distance': 28420.27704455684},
#  {'id': 'aa6aZuV6QXKo9VJzF-mLDg',
#   'alias': 'novelli-wayne',
#   'name': 'Novelli',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LRS3Hruu3Sah7BJOzJPwrA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/novelli-wayne?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 122,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.98973, 'longitude': -74.27858},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '2410 Hamburg Tpke',
#    'address2': '',
#    'address3': '',
#    'city': 'Wayne',
#    'zip_code': '07470',
#    'country': 'US',
#    'state': 'NJ',
#    'display_address': ['2410 Hamburg Tpke', 'Wayne, NJ 07470']},
#   'phone': '+19738353585',
#   'display_phone': '(973) 835-3585',
#   'distance': 39670.160372828665},
#  {'id': 'oDTAnVavrgbBLa9GDY7TUA',
#   'alias': 'tudor-city-steakhouse-new-york',
#   'name': 'Tudor City Steakhouse',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MOXlSbccGa_G8me8a_-duw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tudor-city-steakhouse-new-york?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 100,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 40.749374, 'longitude': -73.9699911},
#   'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#   'price': '$$$',
#   'location': {'address1': '45 Tudor City Pl',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10017',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['45 Tudor City Pl', 'New York, NY 10017']},
#   'phone': '+12126824000',
#   'display_phone': '(212) 682-4000',
#   'distance': 5296.589241810761},
#  {'id': '0AdphkoK3DR7rUxX4sYV4g',
#   'alias': 'tuscany-villa-ristorante-montville',
#   'name': 'Tuscany Villa Ristorante',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/q3KHPUBlq1NFoQQbZGpQUw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tuscany-villa-ristorante-montville?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 53,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'salad', 'title': 'Salad'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.87632, 'longitude': -74.36303},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '223 Changebridge Rd',
#    'address2': '',
#    'address3': None,
#    'city': 'Montville',
#    'zip_code': '07045',
#    'country': 'US',
#    'state': 'NJ',
#    'display_address': ['223 Changebridge Rd', 'Montville, NJ 07045']},
#   'phone': '+19733341400',
#   'display_phone': '(973) 334-1400',
#   'distance': 36408.577312488356},
#  {'id': 'DWVVS482Wj4EdyYAdj_nsA',
#   'alias': 'crown-palace-middletown',
#   'name': 'Crown Palace',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PS6MYV2gY3aHb4LhJhbV4Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/crown-palace-middletown?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 83,
#   'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#    {'alias': 'cantonese', 'title': 'Cantonese'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 40.400315, 'longitude': -74.117901},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1283 Rte 35',
#    'address2': '',
#    'address3': '',
#    'city': 'Middletown',
#    'zip_code': '07748',
#    'country': 'US',
#    'state': 'NJ',
#    'display_address': ['1283 Rte 35', 'Middletown, NJ 07748']},
#   'phone': '+17326159888',
#   'display_phone': '(732) 615-9888',
#   'distance': 35499.67037422459},
#  {'id': 'yVNwo4dnGssgd45s0IHdvw',
#   'alias': 'liberty-house-restaurant-jersey-city-2',
#   'name': 'Liberty House Restaurant',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/K3fS8LymITJuPAu3glXaiA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/liberty-house-restaurant-jersey-city-2?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 510,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.7092002302021,
#    'longitude': -74.0399466756692},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '76 Audrey Zapp Dr',
#    'address2': '',
#    'address3': '',
#    'city': 'Jersey City',
#    'zip_code': '07305',
#    'country': 'US',
#    'state': 'NJ',
#    'display_address': ['76 Audrey Zapp Dr', 'Jersey City, NJ 07305']},
#   'phone': '+12013950300',
#   'display_phone': '(201) 395-0300',
#   'distance': 3870.7809695040173},
#  {'id': '6s4jwmGFq4kUAnOyyN772g',
#   'alias': 'kona-grill-iselin-2',
#   'name': 'Kona Grill',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Yxxb_0eP49y1sOASUBhmgQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/kona-grill-iselin-2?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 662,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.5562967746236,
#    'longitude': -74.3113458892936},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '511 US Highway 1 S',
#    'address2': '',
#    'address3': '',
#    'city': 'Iselin',
#    'zip_code': '08830',
#    'country': 'US',
#    'state': 'NJ',
#    'display_address': ['511 US Highway 1 S', 'Iselin, NJ 08830']},
#   'phone': '+17327504400',
#   'display_phone': '(732) 750-4400',
#   'distance': 31478.521888858246},
#  {'id': 'RJPedMtnDBSH7IVrFgZoIw',
#   'alias': 'assaggini-di-roma-hazlet',
#   'name': 'Assaggini Di Roma',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4z1iEmRQNE_0ebm-Iii1xQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/assaggini-di-roma-hazlet?adjust_creative=jNoG2_OHGxcce7ddjwUN_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jNoG2_OHGxcce7ddjwUN_g',
#   'review_count': 93,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.4199636, 'longitude': -74.1814869},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '3253 State Rt 35 N',
#    'address2': '',
#    'address3': '',
#    'city': 'Hazlet',
#    'zip_code': '07730',
#    'country': 'US',
#    'state': 'NJ',
#    'display_address': ['3253 State Rt 35 N', 'Hazlet, NJ 07730']},
#   'phone': '+17323355900',
#   'display_phone': '(732) 335-5900',
#   'distance': 35464.53842876057},
#  {'id': 'AWeQkgJ0uzNr5YxFr2Bx8g',
#   'alias': 'pasquale-jones-new-york',
#   'name': 'Pasquale Jones',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/
{'alias': 'japanese', 'title': 'Japanese'}, {...
# 2    [{'alias': 'wine_bars', 'title': 'Wine Bars'},...
# 3    [{'alias': 'seafoodmarkets', 'title': 'Seafood...
# 4    [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# 5    [{'alias': 'seafood', 'title': 'Seafood'}, {'a...
# 6    [{'alias': 'seafood', 'title': 'Seafood'}, {'a...
# 7    [{'alias': 'mediterranean', 'title': 'Mediterr...
# 8    [{'alias': 'portuguese', 'title': 'Portuguese'...
# 9                 [{'alias': 'thai', 'title': 'Thai'}]
# 10   [{'alias': 'greek', 'title': 'Greek'}, {'alias...
# 11   [{'alias': 'japanese', 'title': 'Japanese'}, {...
# 12   [{'alias': 'newamerican', 'title': 'American (...
# 13   [{'alias': 'seafood', 'title': 'Seafood'}, {'a...
# 14   [{'alias': 'italian', 'title': 'Italian'}, {'a...
# 15   [{'alias': 'seafood', 'title': 'Seafood'}, {'a...
# 16   [{'alias': 'greek', 'title': 'Greek'}, {'alias...
# 17   [{'alias': 'seafood', 'title': 'Seafood'}, {'a...
# 18   [{'alias': 'seafood', 'title': 'Seafood'}, {'a...
# 19            [{'alias': 'french', 'title': 'French'}]
# 20   [{'alias': 'seafood', 'title': 'Seafood'}, {'a...
# 21   [{'alias': 'italian', 'title': 'Italian'}, {'a...
# 22   [{'alias': 'latin', 'title': 'Latin American'}...
# 23   [{'alias': 'seafood', 'title': 'Seafood'}, {'a...
# 24         [{'alias': 'sushi', 'title': 'Sushi Bars'}]
# 25   [{'alias': 'greek', 'title': 'Greek'}, {'alias...
# 26   [{'alias': 'seafood', 'title': 'Seafood'}, {'a...
# 27   [{'alias': 'steak', 'title': 'Steakhouses'}, {...
# 28            [{'alias': 'diners', 'title': 'Diners'}]
# 29   [{'alias': 'italian', 'title': 'Italian'}, {'a...
# ..                                                 ...
# 970        [{'alias': 'sushi', 'title': 'Sushi Bars'}]
# 971  [{'alias': 'newamerican', 'title': 'American (...
# 972  [{'alias': 'newamerican', 'title': 'American (...
# 973  [{'alias': 'greek', 'title': 'Greek'}, {'alias...
# 974  [{'alias': 'japanese', 'title': 'Japanese'}, {...
# 975  [{'alias': 'italian', 'title': 'Italian'}, {'a...
# 976  [{'alias': 'wine_bars', 'title': 'Wine Bars'},...
# 977         [{'alias': 'spanish', 'title': 'Spanish'}]
# 978  [{'alias': 'brazilian', 'title': 'Brazilian'},...
# 979  [{'alias': 'cocktailbars', 'title': 'Cocktail ...
# 980  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...
# 981  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# 982  [{'alias': 'portuguese', 'title': 'Portuguese'...
# 983  [{'alias': 'gastropubs', 'title': 'Gastropubs'...
# 984  [{'alias': 'venues', 'title': 'Venues & Event ...
# 985  [{'alias': 'diners', 'title': 'Diners'}, {'ali...
# 986  [{'alias': 'italian', 'title': 'Italian'}, {'a...
# 987  [{'alias': 'newamerican', 'title': 'American (...
# 988  [{'alias': 'japanese', 'title': 'Japanese'}, {...
# 989  [{'alias': 'cocktailbars', 'title': 'Cocktail ...
# 990  [{'alias': 'japanese', 'title': 'Japanese'}, {...
# 991  [{'alias': 'fishing', 'title': 'Fishing'}, {'a...
# 992         [{'alias': 'italian', 'title': 'Italian'}]
# 993       [{'alias': 'steak', 'title': 'Steakhouses'}]
# 994  [{'alias': 'italian', 'title': 'Italian'}, {'a...
# 995  [{'alias': 'dimsum', 'title': 'Dim Sum'}, {'al...
# 996  [{'alias': 'newamerican', 'title': 'American (...
# 997  [{'alias': 'newamerican', 'title': 'American (...
# 998         [{'alias': 'italian', 'title': 'Italian'}]
# 999  [{'alias': 'italian', 'title': 'Italian'}, {'a...
#
#                                            coordinates   display_phone  \
# 0         {'latitude': 40.7258, 'longitude': -73.9927}  (212) 677-2223
# 1      {'latitude': 40.731107, 'longitude': -73.98912}  (212) 353-5088
# 2     {'latitude': 40.728901, 'longitude': -73.981185}  (212) 254-5660
# 3    {'latitude': 40.7582645924672, 'longitude': -7...  (646) 918-7560
# 4       {'latitude': 40.73902, 'longitude': -73.99065}  (212) 802-9999
# 5    {'latitude': 40.7547012104496, 'longitude': -7...  (212) 935-3785
# 6    {'latitude': 40.7353962496717, 'longitude': -7...  (212) 691-9359
# 7       {'latitude': 40.7301, 'longitude': -73.863538}  (718) 275-7555
# 8       {'latitude': 40.72991, 'longitude': -74.16067}  (973) 465-1250
# 9     {'latitude': 40.741014, 'longitude': -73.982259}  (212) 689-1444
# 10   {'latitude': 40.7310782469639, 'longitude': -7...  (212) 432-0011
# 11   {'latitude': 40.712622, 'longitude': -73.9487843}  (929) 295-0480
# 12    {'latitude': 40.71647, 'longitude': -74.0095599}  (212) 941-9401
# 13       {'latitude': 40.68396, 'longitude': -74.0018}  (718) 855-2632
# 5    {'address1': '158 E 48th St', 'address2': None...
# 6    {'address1': '259 W 4th St', 'address2': '', '...
# 7    {'address1': '95-36 Queens Blvd', 'address2': ...
# 8    {'address1': '87 Madison St', 'address2': '', ...
# 9    {'address1': '153 E 26th St', 'address2': '', ...
# 10   {'address1': '228 1st Ave', 'address2': '', 'a...
# 11   {'address1': '150 Ainslie St', 'address2': '',...
# 12   {'address1': '134 Reade St', 'address2': '', '...
# 13   {'address1': '144 Union St', 'address2': '', '...
# 14   {'address1': '17 Ave B', 'address2': '', 'addr...
# 15   {'address1': '159 Bridge Park Dr', 'address2':...
# 16   {'address1': '55 E 54th St', 'address2': None,...
# 17   {'address1': '3308 Ditmars Blvd', 'address2': ...
# 18   {'address1': '390 Broome St', 'address2': '', ...
# 19   {'address1': '155 Grand St', 'address2': '', '...
# 20   {'address1': '38-11 Bell Blvd', 'address2': No...
# 21   {'address1': '184 Prince St', 'address2': '', ...
# 22   {'address1': '536 9th Ave', 'address2': '', 'a...
# 23   {'address1': '89 South St', 'address2': 'Pier ...
# 24   {'address1': '33 E 20th St', 'address2': None,...
# 25   {'address1': '28-13 23rd Ave', 'address2': '',...
# 26   {'address1': '37-10 33rd St', 'address2': '', ...
# 27   {'address1': '117 West 58 St', 'address2': Non...
# 28   {'address1': '1236 2nd Ave', 'address2': '', '...
# 29   {'address1': '68 5th Ave', 'address2': '', 'ad...
# ..                                                 ...
# 970  {'address1': '200 Hudson St', 'address2': '', ...
# 971  {'address1': '146 Essex St', 'address2': None,...
# 972  {'address1': '217 Lafayette Ave', 'address2': ...
# 973  {'address1': '2003 Emmons Ave', 'address2': ''...
# 974  {'address1': '44 Essex St', 'address2': '', 'a...
# 975  {'address1': '565 Gorge Rd', 'address2': None,...
# 976  {'address1': '11 W 31st St', 'address2': '', '...
# 977  {'address1': '844 McCarter Hwy', 'address2': '...
# 978  {'address1': '145 Ave C', 'address2': '', 'add...
# 979  {'address1': '506 9th Ave', 'address2': None, ...
# 980  {'address1': '206 Rock Rd', 'address2': '', 'a...
# 981  {'address1': '114 N 6th St', 'address2': '', '...
# 982  {'address1': '157 E Westfield Ave', 'address2'...
# 983  {'address1': '13 E 1st St', 'address2': '', 'a...
# 984  {'address1': '440 Old Country Rd', 'address2':...
# 985  {'address1': '300 W Park Ave', 'address2': '',...
# 986  {'address1': '324 Millburn Ave', 'address2': '...
# 987  {'address1': '4 E 46th St', 'address2': None, ...
# 988  {'address1': '45 N Dean St', 'address2': '', '...
# 989  {'address1': '206 Ave A', 'address2': None, 'a...
# 990  {'address1': '15 E 15th St', 'address2': '', '...
# 991  {'address1': '10 Matinicock', 'address2': None...
# 992  {'address1': '2410 Hamburg Tpke', 'address2': ...
# 993  {'address1': '45 Tudor City Pl', 'address2': N...
# 994  {'address1': '223 Changebridge Rd', 'address2'...
# 995  {'address1': '1283 Rte 35', 'address2': '', 'a...
# 996  {'address1': '76 Audrey Zapp Dr', 'address2': ...
# 997  {'address1': '511 US Highway 1 S', 'address2':...
# 992                          Novelli  +19738353585   $$$     4.5
# 993            Tudor City Steakhouse  +12126824000   $$$     3.0
# 994         Tuscany Villa Ristorante  +19733341400     $     4.0
# 995                     Crown Palace  +17326159888    $$     3.0
# 996         Liberty House Restaurant  +12013950300   $$$     3.5
# 997                       Kona Grill  +17327504400    $$     3.5
# 998                Assaggini Di Roma  +17323355900    $$     4.0
# 999                   Pasquale Jones  +19174530339   $$$     3.5
#
#      review_count                                transactions  \
# 0             651                          [pickup, delivery]
# 1             623                          [pickup, delivery]
# 2             873                          [pickup, delivery]
# 3              24                                          []
# 4            3383                          [pickup, delivery]
# 5            1279                                          []
# 6            1253                          [pickup, delivery]
# 7             346                          [pickup, delivery]
# 8             527                                  [delivery]
# 9             498                          [pickup, delivery]
# 10            828                          [pickup, delivery]
# 11            457                          [pickup, delivery]
# 12            924                          [pickup, delivery]
# 13            318                          [pickup, delivery]
# 14           1116                          [pickup, delivery]
# 15             25                          [pickup, delivery]
# 16            476                          [pickup, delivery]
# 17            136                          [pickup, delivery]
# 18            713                          [pickup, delivery]
# 19            165                          [pickup, delivery]
# 20            363                          [pickup, delivery]
# 21            297                          [pickup, delivery]
# 22            188  [pickup, restaurant_reservation, delivery]
# 23            174                                          []
# 24            831                                          []
# 25            343                          [pickup, delivery]
# 26            700                          [pickup, delivery]
# 27            131                                          []
# 28            137                          [pickup, delivery]
# 29            481                          [pickup, delivery]
# ..            ...                                         ...
# 970           371                          [delivery, pickup]
# 971          3504                          [delivery, pickup]
# 972           580                                  [delivery]
# 973           140                                    [pickup]
# 974           129                          [delivery, pickup]
# 975           256  [delivery, restaurant_reservation, pickup]
# 976          1687  [delivery, restaurant_reservation, pickup]
# 977           303                                  [delivery]
# 978           698                          [delivery, pickup]
# 979            20  [delivery, restaurant_reservation, pickup]
# 980           174                          [delivery, pickup]
# 981          3090                          [delivery, pickup]
# 982            73                                  [delivery]
# 983           754  [delivery, restaurant_reservation, pickup]
# 984           121                                          []
# 985           193                                          []
# 986           180                                    [pickup]
# 987           775                          [delivery, pickup]
# 988           114                          [delivery, pickup]
# 989            89                          [delivery, pickup]
# 990           633                                          []
# 991             3                                          []
# 992           122                                  [delivery]
# 993           100  [delivery, restaurant_reservation, pickup]
# 994            53                                  [delivery]
# 995            83                                  [delivery]
# 996           510                                  [delivery]
# 997           662                          [delivery, pickup]
# 998            93                                  [delivery]
# 999           247                                          []
#
#                                                    url
# 0    https://www.yelp.com/biz/fish-cheeks-new-york?...
# 1    https://www.yelp.com/biz/kotobuki-manhattan-ne...
# 2    https://www.yelp.com/biz/au-zaatar-new-york?ad...
# 3    https://www.yelp.com/biz/midtown-catch-new-yor...
# 4    https://www.yelp.com/biz/thai-villa-new-york-2...
# 5    https://www.yelp.com/biz/the-seafire-grill-new...
# 6    https://www.yelp.com/biz/extra-virgin-new-york...
# 7    https://www.yelp.com/biz/blacksea-fish-and-gri...
# 8    https://www.yelp.com/biz/seabra-marisqueira-ne...
# 9    https://www.yelp.com/biz/little-basil-new-york...
[{'alias': 'seafood', 'title': 'Seafood'}, {'a...  (212) 691-9359
# 7    [{'alias': 'mediterranean', 'title': 'Mediterr...  (718) 275-7555
# 8    [{'alias': 'portuguese', 'title': 'Portuguese'...  (973) 465-1250
# 9                 [{'alias': 'thai', 'title': 'Thai'}]  (212) 689-1444
# 10   [{'alias': 'greek', 'title': 'Greek'}, {'alias...  (212) 432-0011
# 11   [{'alias': 'japanese', 'title': 'Japanese'}, {...  (929) 295-0480
# 12   [{'alias': 'newamerican', 'title': 'American (...  (212) 941-9401
# 13   [{'alias': 'seafood', 'title': 'Seafood'}, {'a...  (718) 855-2632
# 14   [{'alias': 'italian', 'title': 'Italian'}, {'a...  (212) 228-1260
# 15   [{'alias': 'seafood', 'title': 'Seafood'}, {'a...  (718) 521-6744
# 16   [{'alias': 'greek', 'title': 'Greek'}, {'alias...  (212) 759-5554
# 17   [{'alias': 'seafood', 'title': 'Seafood'}, {'a...  (718) 545-2200
# 18   [{'alias': 'seafood', 'title': 'Seafood'}, {'a...  (212) 730-6005
# 19            [{'alias': 'french', 'title': 'French'}]  (212) 343-4295
# 20   [{'alias': 'seafood', 'title': 'Seafood'}, {'a...  (718) 279-1606
# 21   [{'alias': 'italian', 'title': 'Italian'}, {'a...  (212) 625-3200
# 22   [{'alias': 'latin', 'title': 'Latin American'}...  (212) 388-5040
# 23   [{'alias': 'seafood', 'title': 'Seafood'}, {'a...  (212) 838-1200
# 24         [{'alias': 'sushi', 'title': 'Sushi Bars'}]  (347) 705-8100
# 25   [{'alias': 'greek', 'title': 'Greek'}, {'alias...  (718) 728-9056
# 26   [{'alias': 'seafood', 'title': 'Seafood'}, {'a...  (718) 392-2680
# 27   [{'alias': 'steak', 'title': 'Steakhouses'}, {...  (212) 757-8630
# 28            [{'alias': 'diners', 'title': 'Diners'}]  (212) 249-4250
# 29   [{'alias': 'italian', 'title': 'Italian'}, {'a...  (718) 857-1833
# ..                                                 ...             ...
# 970        [{'alias': 'sushi', 'title': 'Sushi Bars'}]  (201) 386-1117
# 971  [{'alias': 'newamerican', 'title': 'American (...  (212) 614-0146
# 972  [{'alias': 'newamerican', 'title': 'American (...  (732) 632-1852
# 973  [{'alias': 'greek', 'title': 'Greek'}, {'alias...  (718) 332-6064
# 974  [{'alias': 'japanese', 'title': 'Japanese'}, {...  (973) 379-4900
# 975  [{'alias': 'italian', 'title': 'Italian'}, {'a...  (201) 313-0802
# 976  [{'alias': 'wine_bars', 'title': 'Wine Bars'},...  (212) 714-2992
# 977         [{'alias': 'spanish', 'title': 'Spanish'}]  (973) 623-4662
# 978  [{'alias': 'brazilian', 'title': 'Brazilian'},...  (212) 505-6559
# 979  [{'alias': 'cocktailbars', 'title': 'Cocktail ...  (212) 564-4950
# 980  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...  (201) 612-1188
# 981  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...  (718) 384-8850
# 982  [{'alias': 'portuguese', 'title': 'Portuguese'...  (908) 259-5907
# 983  [{'alias': 'gastropubs', 'title': 'Gastropubs'...  (212) 228-1200
# 984  [{'alias': 'venues', 'title': 'Venues & Event ...  (516) 334-6125
# 985  [{'alias': 'diners', 'title': 'Diners'}, {'ali...  (516) 432-7728
# 986  [{'alias': 'italian', 'title': 'Italian'}, {'a...  (973) 379-7020
# 987  [{'alias': 'newamerican', 'title': 'American (...  (212) 682-3562
# 988  [{'alias': 'japanese', 'title': 'Japanese'}, {...  (201) 567-9600
# 989  [{'alias': 'cocktailbars', 'title': 'Cocktail ...  (212) 228-6231
# 990  [{'alias': 'japanese', 'title': 'Japanese'}, {...  (212) 647-0015
# 991  [{'alias': 'fishing', 'title': 'Fishing'}, {'a...  (516) 457-8715
# 992         [{'alias': 'italian', 'title': 'Italian'}]  (973) 835-3585
# 993       [{'alias': 'steak', 'title': 'Steakhouses'}]  (212) 682-4000
# 994  [{'alias': 'italian', 'title': 'Italian'}, {'a...  (973) 334-1400
# 995  [{'alias': 'dimsum', 'title': 'Dim Sum'}, {'al
# 989  lF0HXz7jRPftaWu_j0zYOQ
# 990  GBWMJJ4_rDWqiXJ7AvHAOg
# 991  SrdgagoG7fznuNbXkI87Vw
# 992  aa6aZuV6QXKo9VJzF-mLDg
# 993  oDTAnVavrgbBLa9GDY7TUA
# 994  0AdphkoK3DR7rUxX4sYV4g
# 995  DWVVS482Wj4EdyYAdj_nsA
# 996  yVNwo4dnGssgd45s0IHdvw
# 997  6s4jwmGFq4kUAnOyyN772g
# 998  RJPedMtnDBSH7IVrFgZoIw
# 999  AWeQkgJ0uzNr5YxFr2Bx8g
#
#                                               location  \
# 0    {'address1': '55 Bond St', 'address2': '', 'ad...
# 1    {'address1': '56 3rd Ave', 'address2': None, '...
# 2    {'address1': '188 Avenue A', 'address2': '', '...
# 3    {'address1': '405 E 57th St', 'address2': '', ...
# 4    {'address1': '5 E 19th St', 'address2': 'G Flo...
# 5    {'address1': '158 E 48th St', 'address2': None...
# 6    {'address1': '259 W 4th St', 'address2': '', '...
# 7    {'address1': '95-36 Queens Blvd', 'address2': ...
# 8    {'address1': '87 Madison St', 'address2': '', ...
# 9    {'address1': '153 E 26th St', 'address2': '', ...
# 10   {'address1': '228 1st Ave', 'address2': '', 'a...
# 11   {'address1': '150 Ainslie St', 'address2': '',...
# 12   {'address1': '134 Reade St', 'address2': '', '...
# 13   {'address1': '144 Union St', 'address2': '', '...
# 14   {'address1': '17 Ave B', 'address2': '', 'addr...
# 15   {'address1': '159 Bridge Park Dr', 'address2':...
# 16   {'address1': '55 E 54th St', 'address2': None,...
# 17   {'address1': '3308 Ditmars Blvd', 'address2': ...
# 18   {'address1': '390 Broome St', 'address2': '', ...
# 19   {'address1': '155 Grand St', 'address2': '', '...
# 20   {'address1': '38-11 Bell Blvd', 'address2': No...
# 21   {'address1': '184 Prince St', 'address2': '', ...
# 22   {'address1': '536 9th Ave', 'address2': '', 'a...
# 23   {'address1': '89 South St', 'address2': 'Pier ...
# 24   {'address1': '33 E 20th St', 'address2': None,...
# 25   {'address1': '28-13 23rd Ave', 'address2': '',...
# 26   {'address1': '37-10 33rd St', 'address2': '', ...
# 27   {'address1': '117 West 58 St', 'address2': Non...
# 28   {'address1': '1236 2nd Ave', 'address2': '', '...
# 29   {'address1': '68 5th Ave', 'address2': '', 'ad...
# ..                                                 ...
# 970  {'address1': '200 Hudson St', 'address2': '', ...
# 971  {'address1': '146 Essex St', 'address2': None,...
# 972  {'address1': '217 Lafayette Ave', 'address2': ...
# 973  {'address1': '2003 Emmons Ave', 'address2': ''...
# 974  {'address1': '44 Essex St', 'address2': '', 'a...
# 975  {'address1': '565 Gorge Rd', 'address2': None,...
# 976  {'address1': '11 W 31st St', 'address2': '', '...
# 977  {'address1': '844 McCarter Hwy', 'address2': '...
# 978  {'address1': '145 Ave C', 'address2': '', 'add...
# 979  {'address1': '506 9th Ave', 'address2': None, ...
# 980  {'address1': '206 Rock Rd', 'address2': '', 'a...
# 981  {'address1': '114 N 6th St', 'address2': '', '...
# 976  https://www.yelp.com/biz/ayza-wine-and-chocola...
# 977  https://www.yelp.com/biz/don-pepe-newark?adjus...
# 978  https://www.yelp.com/biz/esperanto-new-york?ad...
# 979  https://www.yelp.com/biz/the-restaurant-new-yo...
# 980  https://www.yelp.com/biz/tani-sushi-and-asian-...
# 981  https://www.yelp.com/biz/sea-brooklyn-2?adjust...
# 982  https://www.yelp.com/biz/vinhus-restaurant-and...
# 983  https://www.yelp.com/biz/baar-baar-new-york-2?...
# 984  https://www.yelp.com/biz/chateau-briand-catere...
# 985  https://www.yelp.com/biz/laurel-diner-long-bea...
# 986  https://www.yelp.com/biz/basilico-millburn-2?a...
# 987  https://www.yelp.com/biz/vitae-new-york?adjust...
# 988  https://www.yelp.com/biz/daruma-japanese-resta...
# 989  https://www.yelp.com/biz/the-garret-new-york-2...
# 990  https://www.yelp.com/biz/15-east-restaurant-ne...
# 991  https://www.yelp.com/biz/american-sportfishing...
# 992  https://www.yelp.com/biz/novelli-wayne?adjust_...
# 993  https://www.yelp.com/biz/tudor-city-steakhouse...
# 994  https://www.yelp.com/biz/tuscany-villa-ristora...
# 995  https://www.yelp.com/biz/crown-palace-middleto...
# 996  https://www.yelp.com/biz/liberty-house-restaur...
# 997  https://www.yelp.com/biz/kona-grill-iselin-2?a...
# 998  https://www.yelp.com/biz/assaggini-di-roma-haz...
# 999  https://www.yelp.com/biz/pasquale-jones-new-yo...
#
# [1000 rows x 10 columns]

# %%
#df.to_csv (r'C:\Users\leroy\Desktop\cleandatayelp.csv', index = True, header=True)

# %%
#testing
df.location[1]["display_address"]

# %%
df.categories[1]

# %%
df.categories[0][0]["alias"]

# %%
df.categories[0][0]["title"]

# %%
df.categories[1][0]["title"]

# %%
df.categories[2][0]["title"]

# %%
#drop null data values- price seems to be missing
#---
df.drop('price', axis=1)
df = df.dropna(axis=0)
df = df.reset_index(drop=True)

# %%
df.shape
len(df)

# %%
df.info()

# %%
#split link
df[['new_url2', 'new_url3']]=df['url'].str.split('?', expand=True,n=2)

# %%
df['new_url2']

# %%
df['new_url2'] = df['new_url2'] + '?'

# %%
#creating a dummy new column
df["New_Category"] = df.categories

# %%
#creating a dummy new column
df["New_zip_code"] = df.location

# %%
#creating a dummy new column
df["new_ID"] = df["id"]

# %%
#creating a dummy new column
df["URL"] = df["new_url2"]

# %%
#creating a dummy new column
df["Updated_city"] = df.location

# %%
df.location[1]["city"]

# %%
df.location[1]["zip_code"]

# %%
#creating a new dummy column for city, zip code, and food category
counting = 0
for k in range(0,len(df)):
    df["New_Category"][k] = df.categories[k][0]["title"]
    df["Updated_city"][k] = df.location[k]["city"]
    df["New_zip_code"][k] = df.location[k]["zip_code"] 
    #df["URL"][k] = df['URL'][k] + "?"
    #df["URL"][k] = df["new_url2"][k] + "?"
    #print("No:" + str(counting))
    #print("URL:", df.URL[k])
    #print("\n")
    #counting = counting + 1

# %%
df["Updated_city"]

# %%
df["New_Category"]

# %%
df['URL']

# %%
# Create new table under df_graph

df_graph = df[["name", "new_ID","URL","New_Category", "price", "rating",
                           "Updated_city", "review_count","location","New_zip_code"]]

df_graph.index.name = 'Index'
df_graph.head(5)

# %%
# grouped = us_restaurants.city.value_counts()[:10]


new_cat = df_graph["New_Category"].value_counts()[:10]
new_cat.head()

# %%
new_cat[3]

# %%
rat_group = df_graph.groupby('rating')
rat_group

# %%
rat_cat_group = rat_group['rating'].count()
rat_cat_group.head

# %%
rate_chart = rat_cat_group.plot(kind='barh', figsize=(8, 10), color='#86bf91', zorder=-1, width=0.5, title='Ratings View')

# %%
cat_group = df_graph.groupby('New_Category')

# %%
count_cat_group = cat_group['New_Category'].count().sort_values(ascending = False)[:10]
count_cat_group.head(5)

# %%
count_chart= new_cat.plot(kind='barh')

# %%
plt.figure(figsize=(11,7))
grouped = df_graph.groupby('New_Category')['review_count'].sum().sort_values(ascending = False)[:10]
sns.barplot(y=grouped.index, x= grouped.values, palette= sns.color_palette("RdBu_r", len(grouped)) )
plt.ylabel('Category', fontsize=14)
plt.xlabel('Count of reviews', fontsize=14)
plt.title('Count of Reviews by Cuisine Type for 1000 restaurants', fontsize=15)
for i,v in enumerate(grouped):
    plt.text(v, i+0.15, str(v),fontweight='bold', fontsize=14)
plt.tick_params(labelsize=14)

# %%
count_chart = new_cat.plot(kind='barh', figsize=(8, 10), color='#86bf91', zorder=-1, width=0.5, title='Top 10 categories')

# %%
# Create a bar chart based off of the group series from before
count_chart = new_cat.plot(kind='bar', title='Top 10 categories')

# Set the xlabel and ylabel using class methods
count_chart.set_xlabel("Number of restaurants")
count_chart.set_ylabel("Count of Restaurants by Category")
for index,data in enumerate(new_cat):
    plt.text(x=index, y =data+4, s=f"{data}", horizontalalignment ='center',color='green', fontdict=dict(fontsize=14), va='center')
plt.show()
plt.tight_layout()

# %%
df_graph

# %%
# TOP 10 Restaurants with Most Reviews
plt.figure(figsize=(11,6))
grouped = df_graph[['name','review_count']].sort_values(by='review_count', ascending=False)[:10]
sns.barplot(x=grouped.review_count, y = grouped.name, palette=sns.color_palette("GnBu_r", len(grouped)), ci=None)
plt.xlabel('Count of Review', labelpad=10, fontsize=14)
plt.ylabel('Restaurants', fontsize=14)
plt.title('TOP 10 NYC Restaurants with Most Reviews for seabass', fontsize=15)
plt.tick_params(labelsize=14)
plt.xticks(rotation=15)
for  i, v in enumerate(grouped.review_count):
    plt.text(v, i, str(v), fontweight='bold', color='blue', fontsize=14)

# %%
plt.style.use('ggplot')

# %%
plt.figure(figsize=(11,6))


grouped = df_graph.groupby('New_zip_code')['review_count'].sum().sort_values(ascending=False)[:10]
grouped_df = pd.DataFrame(grouped.reset_index())
print(grouped_df)
grouped_df.columns =["New_zip_code","review_count"]

grouped_df = grouped_df.sort_values(['review_count'],ascending=False).reset_index(drop=True)


ax = sns.barplot(grouped_df.index, grouped_df.review_count,palette=sns.color_palette("GnBu_r", len(grouped_df))) 
plt.xlabel('Zipcode', labelpad=10, fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.title('Count of Reviews by Zip Code in NYC (Top 10)', fontsize=15)
plt.tick_params(labelsize=14)
plt.xticks(rotation=90)
for  i, v in enumerate(grouped):
    plt.text(i, v*1.02, str(v), horizontalalignment ='center',color='blue',rotation=45,fontweight='bold', fontsize=14)
    

ax.set_xticklabels(grouped_df.New_zip_code)
for item in ax.get_xticklabels(): item.set_rotation(45)

# %%
df

# %%
# label reviews as positive or negative
df['labels'] = ''
df.loc[df.rating >=4, 'labels'] = 'positive'
df.loc[df.rating ==3, 'labels'] = 'neural'
df.loc[df.rating <3, 'labels'] = 'negative'

# drop neutral reviews for easy analysis
df.drop(df[df['labels'] =='neural'].index, axis=0, inplace=True)
df.reset_index(drop=True, inplace=True)

df.head()

# %%
# Calculate the earliest/latest year a book was published
least_rev = df_graph["review_count"].min()
most_rev = df_graph["review_count"].max()

# %%
top_reviews = df_graph.nlargest(5,['review_count'])

# %%
top_reviews

# %%
#Top 3 most reviews resturants based on search terms'seabass'
top_reviews['URL'].iloc[0]
top_reviews['URL'].iloc[1]
top_reviews['URL'].iloc[2]
top_reviews['URL'].iloc[3]
top_reviews['URL'].iloc[4]

# %%
#Top 3 recommended resturants based on search terms 'seabass'
df_graph['URL'].loc[0] # fish-cheeks
df_graph['URL'].loc[1] # kotobuki
df_graph['URL'].loc[2] # midtown catch
df_graph['URL'].loc[3] # au-zaata
df_graph['URL'].loc[4] # thai-villa

# %%
df_graph['URL'].loc[2]

# %%
#------------------------------------------------------------
#Searching for Top 3 resturants on the word frequency

# %%
#Importing packages, Dependencies
from selenium import webdriver
from splinter import Browser
import urllib
from bs4 import BeautifulSoup
import time
import requests
import json
import numpy as np

import nltk
from nltk.tokenize import sent_tokenize
from nltk.stem import WordNetLemmatizer
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
# importing module for regex 
import re
cList = {
  "ain't": "am not",
  "aren't": "are not",
  "can't": "cannot",
  "can't've": "cannot have",
  "'cause": "because",
  "could've": "could have",
  "couldn't": "could not",
  "couldn't've": "could not have",
  "didn't": "did not",
  "doesn't": "does not",
  "don't": "do not",
  "hadn't": "had not",
  "hadn't've": "had not have",
  "hasn't": "has not",
  "haven't": "have not",
  "he'd": "he would",
  "he'd've": "he would have",
  "he'll": "he will",
  "he'll've": "he will have",
  "he's": "he is",
  "how'd": "how did",
  "how'd'y": "how do you",
  "how'll": "how will",
  "how's": "how is",
  "I'd": "I would",
  "I'd've": "I would have",
  "I'll": "I will",
  "I'll've": "I will have",
  "I'm": "I am",
  "I've": "I have",
  "isn't": "is not",
  "it'd": "it had",
  "it'd've": "it would have",
  "it'll": "it will",
  "it'll've": "it will have",
  "it's": "it is",
  "let's": "let us",
  "ma'am": "madam",
  "mayn't": "may not",
  "might've": "might have",
  "mightn't": "might not",
  "mightn't've": "might not have",
  "must've": "must have",
  "mustn't": "must not",
  "mustn't've": "must not have",
  "needn't": "need not",
  "needn't've": "need not have",
  "o'clock": "of the clock",
  "oughtn't": "ought not",
  "oughtn't've": "ought not have",
  "shan't": "shall not",
  "sha'n't": "shall not",
  "shan't've": "shall not have",
  "she'd": "she would",
  "she'd've": "she would have",
  "she'll": "she will",
  "she'll've": "she will have",
  "she's": "she is",
  "should've": "should have",
  "shouldn't": "should not",
  "shouldn't've": "should not have",
  "so've": "so have",
  "so's": "so is",
  "that'd": "that would",
  "that'd've": "that would have",
  "that's": "that is",
  "there'd": "there had",
  "there'd've": "there would have",
  "there's": "there is",
  "they'd": "they would",
  "they'd've": "they would have",
  "they'll": "they will",
  "they'll've": "they will have",
  "they're": "they are",
  "they've": "they have",
  "to've": "to have",
  "wasn't": "was not",
  "we'd": "we had",
  "we'd've": "we would have",
  "we'll": "we will",
  "we'll've": "we will have",
  "we're": "we are",
  "we've": "we have",
  "weren't": "were not",
  "what'll": "what will",
  "what'll've": "what will have",
  "what're": "what are",
  "what's": "what is",
  "what've": "what have",
  "when's": "when is",
  "when've": "when have",
  "where'd": "where did",
  "where's": "where is",
  "where've": "where have",
  "who'll": "who will",
  "who'll've": "who will have",
  "who's": "who is",
  "who've": "who have",
  "why's": "why is",
  "why've": "why have",
  "will've": "will have",
  "won't": "will not",
  "won't've": "will not have",
  "would've": "would have",
  "wouldn't": "would not",
  "wouldn't've": "would not have",
  "y'all": "you all",
  "y'alls": "you alls",
  "y'all'd": "you all would",
  "y'all'd've": "you all would have",
  "y'all're": "you all are",
  "y'all've": "you all have",
  "you'd": "you had",
  "you'd've": "you would have",
  "you'll": "you you will",
  "you'll've": "you you will have",
  "you're": "you are",
  "you've": "you have"
}

c_re = re.compile('(%s)' % '|'.join(cList.keys()))

def expandContractions(text, c_re=c_re):
    def replace(match):
        return cList[match.group(0)]
    return c_re.sub(replace, text.lower())

# %%
# URL of page to be scraped
url_top1 = top_reviews['URL'].iloc[0]
url_top2 = top_reviews['URL'].iloc[1]
url_top3 = top_reviews['URL'].iloc[2]
url_top4 = top_reviews['URL'].iloc[3]
url_top5 = top_reviews['URL'].iloc[4]

url_rec1 = df_graph['URL'].loc[0]
url_rec2 = df_graph['URL'].loc[1]
url_rec3 = df_graph['URL'].loc[2]
url_rec4 = df_graph['URL'].loc[3]
url_rec5 = df_graph['URL'].loc[4]

url_rec3

# %%
# Retrieve page with the requests module
#response = requests.get(url_top1)
response = requests.get(url_rec3)

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %%
#Seabass
#url_top1
#url_top2
#url_top3
#url_rec1
#url_rec2
url_rec3


start = 0
num_pages = 7
end = 20* num_pages
x = 1
reviews = []
quote_add = []

while (start < end):
    try:
        new_url = url_rec3 + 'start=' + str(start)
        start +=20
        print (new_url)
        response = requests.get(new_url)
        soup = BeautifulSoup(response.text, "html.parser")
    #print(soup.prettify())
    #instructions = recipeSoup.find('div', class_='hidden').text
    #right_table4=soup.find_all('p', itemprop='description')
        quotes = soup.find_all('span', class_ = 'lemon--span__373c0__3997G raw__373c0__3rKqk')
        for quote in quotes:
            x = x+1
            print('Review:', x, '-------------')
            print(quote.text)
            quote_add.append(quote.text)
#-------------------------------------------------------------------newly added
#Makes all the letters lower in reviews
            review = quote.text.lower()
#expandContractions will put the dictionary made earlier to replace the contractions in the reviews
#Make sure to to run the cList dict cell or else there will be an error
            expandContractions(review)
#Cleaning the lemmas or words in reviews now will make it easier when we start predictive modeling
            words = word_tokenize(review)
            words = word_tokenize(review.replace('\n',' '))
            clean_words = [word.lower() for word in words if word not in set(string.punctuation)]
            characters_to_remove = ["''",'``','...']
            clean_words = [word for word in clean_words if word not in set(characters_to_remove)]
            english_stops = set(stopwords.words('english'))
            clean_words = [word for word in clean_words if word not in english_stops]
            wordnet_lemmatizer = WordNetLemmatizer()
            lemma_list = [wordnet_lemmatizer.lemmatize(word) for word in clean_words]
            #lemma_list = str.replace(right_table4.get_text(strip=True),". ",".")
            reviews.append(lemma_list)
    #reviews.add(a)
    except:
    #reviews.append(right_table4)
        time.sleep(5)
    #print("Reviews:", a,"\n")
        page = urllib.request.urlopen(url)
        soup = BeautifulSoup(page)

# %%
#uncleaned
reviews_collect = pd.DataFrame(quote_add, columns=['reviews'])
reviews_collect.head()

# %%
#saving reviews to csv
reviews_collect.to_csv (r'C:\Users\leroy\Desktop\reviews6.csv', index = True, header=True)

# %%
reviews_collect

# %%
reviews

# %%
quote_add

# %%
#cleaned
reviews_collect_cleaned = pd.DataFrame(np.array(reviews), columns=['review'])
reviews_collect_cleaned.head()

# %%
from collections import defaultdict
word_name = []
y = 0

word_freq = defaultdict(int)

for text in quote_add:
    text = text.lower()
    
    text = text.replace(',', '')
    text = text.replace('.', '')
    text = text.replace('-', '')
    text = text.replace('/', '')
    text = text.replace('?', '')
    text = text.replace(')', '')
    text = text.replace('(', '')
    text = text.replace('!!', '')
    text = text.replace('"', '')
    text = text.replace('!', '')
    text = text.replace('', '')
    text = text.replace(':', '')
    text = text.replace(';', '')
    #cleaning
    #try:
          #method = str.replace(text.get_text(strip=True),". ","")
          #method = str.replace(method, ". ", ".")
          #method = str.replace(method, ".",".\n")
          #method = str.replace(method,", ","") 
        
    print(text)  
    #except AttributeError:
          #print("exit")
    for word in text.split():
        if word == "here":
            word = word.replace('here','')
        if word == "came":
            word = word.replace('came','')
        if word == "would":
            word = word.replace('would','')    
        if word == "go":
            word = word.replace('go','')
        if word == "out":
            word = word.replace('out','')
        if word == "by":
            word = word.replace('by','')    
        if word == "our":
            word = word.replace('our','')
        if word == "from":
            word = word.replace('from','')
        if word == "some":
            word = word.replace('some','')
        if word == "us":
            word = word.replace('us','')
        if word == "or":
            word = word.replace('or','')    
        if word == "can":
            word = word.replace('can','')    
        if word == "all":
            word = word.replace('all','')
        if word == "your":
            word = word.replace('your','')
        if word == "also":
            word = word.replace('also','')
        if word == "it's":
            word = word.replace("it's",'')    
        if word == "only":
            word = word.replace('only','')
        if word == "there":
            word = word.replace('there','')
        if word == "their":
            word = word.replace('their','')
        if word == "get":
            word = word.replace('get','')
        if word == "other":
            word = word.replace('other','')    
        if word == "a":
            word = word.replace('a','')
        if word == "to":
            word = word.replace('to','')
        if word == "i":
            word = word.replace('i','')
        if word == "of":
            word = word.replace('of','')
        if word == "is":
            word = word.replace('is','')
        if word == "was":
            word = word.replace('was','')
        if word == "in":
            word = word.replace('in','')
        if word == "for":
            word = word.replace('for','')
        if word == "it":
            word = word.replace('it','')
        if word == "with":
            word = word.replace('with','')
        if word == "when":
            word = word.replace('when','')
        if word == "which":
            word = word.replace('which','')
        if word == "just":
            word = word.replace('just','')    
        if word == "you":
            word = word.replace('you','')
        if word == "we":
            word = word.replace('we','')
        if word == "but":
            word = word.replace('but','')            
        if word == "this":
            word = word.replace('this','')
        if word == "that":
            word = word.replace('that','')
        if word == "be":
            word = word.replace('be','')
        if word == "my":
            word = word.replace('my','')    
        if word == "have":
            word = word.replace('have','')
        if word == "if":
            word = word.replace('if','')
        if word == "at":
            word = word.replace('at','')    
        if word == "had":
            word = word.replace('had','')    
        if word == "and":    
            word = word.replace('and', '')
        if word == "come":    
            word = word.replace('come', '')
        if word == "got":    
            word = word.replace('got', '')    
        if word == "the":        
            word = word.replace('the', '')
        if word == "as":        
            word = word.replace('as', '')    
        if word == "they":        
            word = word.replace('they', '')
        if word == "are":        
            word = word.replace('are', '')
        if word == "on":        
            word = word.replace('on', '')
        if word == "so":        
            word = word.replace('so', '')
        if word == "were":        
            word = word.replace('were', '')    
        if word == "dumpling":        
            word = word.replace("dumpling", "dumplings")
        if word == "dumplingss":        
            word = word.replace("dumplingss", "dumplings")
        if word != '':    
            word_freq[word] += 1
        #word_name.append(word)
        #word_freq['test'] = word_freq['test'].append(word)
        #word_name = word_name.append(word)
        y = y+1
        print('Word Counting:', y, '-------------')
        print(word)
        #word_name.append(word)

word_freq_df = pd.DataFrame.from_dict(word_freq, orient='index') \
.sort_values(0, ascending=False) \
.rename(columns={0: 'Word_freq'}) \

word_freq_df.index.name = 'Word'

# %%
#temp saving
word_freq_df.to_csv (r'C:\Users\leroy\Desktop\seabassyelpmostrecom3.csv', index = True, header=True)

# %%
from sqlalchemy import create_engine
# Imports the methods needed to abstract classes into tables
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import MetaData
Base = declarative_base()

# Allow us to declare column types
from sqlalchemy import Column, Integer, String, Float 



#Connect to local database
rds_connection_string = "postgres:2305nseW@localhost:5432/yelp_review_db"
engine = create_engine(f'postgresql://{rds_connection_string}')
conn = engine.connect()

# %%
engine.table_names()
# Out:
# ['sb_yelpmostrecomm1',
#  'sb_top_reviews3',
#  'sb_yelp_mostrecomm2',
#  'sb_yelp_mostrecomm3',
#  'new2_sb_EatalyFlatiron_db',
#  'new3_sb_IppudoWestside_db',
#  'new1_sb_shanghaijoe_db',
#  'sb_top_reviews1',
#  'sb_top_reviews2',
#  'toprevframes']

# %%
#Use pandas to load csv converted DataFrame into database
#new_customer_data_df.to_sql(name='Yelp_reviews_seabass', con=engine, if_exists='append', index=False)

# %%
#Confirm data has been added by querying the customer_name table top 20 words mentioned

new1_sb_shanghaijoe_db = pd.read_sql_query('select * from sb_top_reviews1', con=engine).head(20)

# %%
new2_sb_EatalyFlatiron_db = pd.read_sql_query('select * from sb_top_reviews2', con=engine).head(20)

# %%
new3_sb_IppudoWestside_db = pd.read_sql_query('select * from sb_top_reviews3', con=engine).head(20)

# %%
#drop common words to satify top 20 words relating to food

# %%
#to_drop = ['the', 'and', ]
#new1_seabass_shanghaijoe_db[~new1_seabass_shanghaijoe_db['word'].isin(to_drop)]

# %%
new1_sb_shanghaijoe_db['id'] = ''

# %%
new1_sb_shanghaijoe_db.head()
# Out:
#         word  word_freq id
# 0  dumplings        360
# 1       soup        304
# 2        not        152
# 3       good        119
# 4       pork        118

# %%
#new1_sb_shanghaijoe_db.astype({'id': 'int64'}).dtypes

# %%
new2_sb_EatalyFlatiron_db['id'] = ""

# %%
new2_sb_EatalyFlatiron_db.head()
# Out:
#      word  word_freq id
# 0   place        111
# 1    food         84
# 2   pasta         83
# 3     not         81
# 4  eataly         79

# %%
new3_sb_IppudoWestside_db['id'] = ''

# %%
new3_sb_IppudoWestside_db.head()
# Out:
#      word  word_freq id
# 0   ramen        314
# 1     not        124
# 2    good        122
# 3   broth        111
# 4  ippudo        107

# %%
new2_sb_EatalyFlatiron_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
# word         20 non-null object
# word_freq    20 non-null int64
# id           20 non-null object
# dtypes: int64(1), object(2)
# memory usage: 560.0+ bytes

# %%
new2_sb_EatalyFlatiron_db
# Out:
#           word  word_freq id
# 0        place        111
# 1         food         84
# 2        pasta         83
# 3          not         81
# 4       eataly         79
# 5         good         74
# 6      italian         74
# 7          one         59
# 8        great         56
# 9         time         51
# 10        like         49
# 11      really         49
# 12       pizza         49
# 13   delicious         46
# 14        very         46
# 15  restaurant         45
# 16        love         45
# 17       fresh         45
# 18  experience         44
# 19          an         42

# %%
new3_sb_IppudoWestside_db
# Out:
#          word  word_freq id
# 0       ramen        314
# 1         not        124
# 2        good        122
# 3       broth        111
# 4      ippudo        107
# 5        pork        101
# 6        wait         97
# 7       place         88
# 8     noodles         87
# 9        very         87
# 10       buns         67
# 11      spicy         67
# 12     really         63
# 13      great         62
# 14       like         60
# 15        one         58
# 16       food         57
# 17       time         57
# 18  delicious         54
# 19        bar         53

# %%
#Combing all 3 dataframes and placing unique Id on the word
frames = [new1_sb_shanghaijoe_db, new2_sb_EatalyFlatiron_db, new3_sb_IppudoWestside_db]

result = pd.concat(frames).reset_index(drop=True) #resetting the indexes

# %%
result['id'] = ''

# %%
result['id'] = result.groupby(['word']).ngroup()

# %%
toprevframes = result

# %%
#switching varible
toprevframes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 3 columns):
# word         60 non-null object
# word_freq    60 non-null int64
# id           60 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 1.5+ KB

# %%
#creating a unique id column for word between top reviews 1st and 2nd
zcounter = 0
for z in range(0,len(result)):
    for y in range(0,len(new2_sb_EatalyFlatiron_db)):
        if result['word'][z] == new2_sb_EatalyFlatiron_db['word'][y]:
            new2_sb_EatalyFlatiron_db['id'][y] = result['id'][z]
            #print ("found " + str(new2_sb_EatalyFlatiron_db['id'][z]))
        if result['word'][z] == new1_sb_shanghaijoe_db['word'][y]:
            new1_sb_shanghaijoe_db['id'][y] = result['id'][z]    
        if result['word'][z] == new3_sb_IppudoWestside_db['word'][y]:
            new3_sb_IppudoWestside_db['id'][y] = result['id'][z]
            #print ("found " + str(new3_sb_IppudoWestside_db['id'][z]))
                       

    for w in range(0,len(new1_sb_shanghaijoe_db)):        
        if result['word'][z] == new2_sb_EatalyFlatiron_db['word'][w]:
            new2_sb_EatalyFlatiron_db['id'][w] = result['id'][z]
            #print ("found " + str(new2_sb_EatalyFlatiron_db['id'][z]))
        if result['word'][z] == new1_sb_shanghaijoe_db['word'][w]:
            new1_sb_shanghaijoe_db['id'][w] = result['id'][z]    
        if result['word'][z] == new3_sb_IppudoWestside_db['word'][w]:
            new3_sb_IppudoWestside_db['id'][w] = result['id'][z]
            #print ("found " + str(new3_sb_IppudoWestside_db['id'][z]))
            
#     for y in range(0,len(new3_sb_IppudoWestside_db)):
#         if result['word'][z] == new3_sb_IppudoWestside_db['word'][y]:
#             new3_sb_IppudoWestside_db['id'][y] = result['id'][z]
#             print ("found " + str(new3_sb_IppudoWestside_db['id'][z]))
#             break
        
        
        
        #if new2_sb_EatalyFlatiron_db['word'][y] != new1_sb_shanghaijoe_db['word'][z]:
        #    print ("putting in new " + str(y))
            #new2_sb_EatalyFlatiron_db['id'][y] =  new2_sb_EatalyFlatiron_db['id'][y] + str(20 + zcounter)
            #zcounter = zcounter + 1
            #print ("not found " + str(new2_sb_EatalyFlatiron_db['id'][z]))
        #else:
        #    print ("error")
   

    
#this code works

# %%
new2_sb_EatalyFlatiron_db.head()

# %%
new1_sb_shanghaijoe_db.info()

# %%
new2_sb_EatalyFlatiron_db.info()

# %%
new3_sb_IppudoWestside_db

# %%
#converting object to int for id column
new1_sb_shanghaijoe_db["id"] = new1_sb_shanghaijoe_db["id"].astype(str).astype(int)

#converting object to int for id column
new2_sb_EatalyFlatiron_db["id"] = new2_sb_EatalyFlatiron_db["id"].astype(str).astype(int)

#converting object to int for id column
new3_sb_IppudoWestside_db["id"] = new3_sb_IppudoWestside_db["id"].astype(str).astype(int)

print(new3_sb_IppudoWestside_db.dtypes)
print(new2_sb_EatalyFlatiron_db.dtypes)
print(new1_sb_shanghaijoe_db.dtypes)

# %%
new3_sb_IppudoWestside_db.head()

# %%
#showing all the tables in the database
engine.table_names()

# %%
#Query one of the tabel content


sb_top_reviews1_db = pd.read_sql_query('select * from sb_top_reviews1', con=engine)
sb_top_reviews1_db.head

# %%
# inserting table into database
# new2_sb_EatalyFlatiron_db.to_sql('new2_sb_EatalyFlatiron_db', engine)
# new3_sb_IppudoWestside_db.to_sql('new3_sb_IppudoWestside_db', engine)
# new1_sb_shanghaijoe_db.to_sql('new1_sb_shanghaijoe_db', engine)
# toprevframes.to_sql('toprevframes', engine)

# %%
# Create a "Metadata" Layer That Abstracts our SQL Database
# ----------------------------------
#Base.metadata.create_all(engine)

# Use this to clear out the db
# ----------------------------------
Base.metadata.drop_all(engine)

# %%
#showing all the tables in the database
engine.table_names()

# %%
#Query one of the tabel content - Eataly
sb_top_reviews2_db = pd.read_sql_query('select * from sb_top_reviews2', con=engine)
sb_top_reviews2_db.head()

# %%
#Sentiment analysis
## Compute sentiment score (positive score - negative score)
## Return a sentiment polarity score: 1 = positive, 0 = negative

# %%
import csv

# %%
sb_top_reviews1_db

# %%
## import positive file which contains common meaningless positive words such as good
file_positive = open('positive.txt')
reader =csv.reader(file_positive)
positive_words = [word[0] for word in reader]

## import negative file which contains common meaningless positive words such as bad
file_negative = open('negative.txt')
reader =csv.reader(file_negative)
negative_words = [word[0] for word in reader]

# %%
## only keep positive and negative words
def filter_words(review):
    words = [word for word in review.split() if word in positive_words + negative_words]
    words = ' '.join(words)
    return words

# %%
sb_top_reviews1_db['label'] =''
sb_top_reviews1_db['Outcome'] =''
sb_top_reviews1_db.head()

# %%
negative_words

# %%
y = 0
for z in range(0,len(sb_top_reviews1_db)):
    
    for word in positive_words:
        if word == sb_top_reviews1_db['word'][z]:
            sb_top_reviews1_db['label'][z] ='positive'
            sb_top_reviews1_db["Outcome"][z] = 1
            print ("this is running-positive" +str(y)+ word)
            print (sb_top_reviews1_db['label'][z])
            y =y +1
            break;  
    for negword in negative_words:        
        if negword == sb_top_reviews1_db['word'][z]:
            sb_top_reviews1_db['label'][z] ='negative'
            sb_top_reviews1_db["Outcome"][z] = 0
            print ("this is running-negative")
            y =y +1
            break;
    if sb_top_reviews1_db['label'][z] =='':
            sb_top_reviews1_db['label'][z] ='neutral'            
            sb_top_reviews1_db['Outcome'][z] = 2
            print ("this is running-neutral" +str(y))
            y =y +1
             
         
            
                
z = z + 1

# %%
sb_top_reviews1_db['label'].value_counts()

# %%
sb_top_reviews1_db.head()
sb_top_reviews1_db['label'].value_counts()


top10pos1 = sb_top_reviews1_db[sb_top_reviews1_db['label'].str.match('positive')][:10]
top10pos1

top10neg1 = sb_top_reviews1_db[sb_top_reviews1_db['label'].str.match('negative')][:10]
top10neg1.reset_index(drop=True, inplace=True)# resets the index
top10neg1.index.name = 'Index'
top10neg1

# %%
frames = [top10pos1, top10neg1]

result_polar = pd.concat(frames)
result_polar.reset_index(drop=True, inplace=True)
result_polar.index.name = 'Index'
result_polar

# %%
plt.figure(figsize=(11,6))
colors = ['red' if c == 'negative' else 'blue' for c in result_polar.label]
sns.barplot(y=result_polar.word, x=result_polar.word_freq, palette=colors)
plt.xlabel('Word Frequency', labelpad=10, fontsize=14)
plt.ylabel('Words', fontsize=14)
plt.title('TOP 10 Positive & Negative Words in Shanghai Joe Restaurant Reviews', fontsize=15)
plt.tick_params(labelsize=14)
plt.xticks(rotation=15)
for  i, v in enumerate(result_polar.word_freq):
    plt.text(v, i+0.25, str(v), fontweight='bold', color='green', fontsize=14)

# %%
#Query Fish cheek restaurant of the table content
sb_yelp_mostrecomm3 = pd.read_sql_query('select * from sb_yelp_mostrecomm3', con=engine)
sb_yelp_mostrecomm3

# %%
sb_yelp_mostrecomm3.to_csv (r'C:\Users\leroy\Desktop\reviews7.csv', index = True, header=True)

# %%
sb_yelp_mostrecomm3['label'] =''
sb_yelp_mostrecomm3['Outcome'] =''
sb_yelp_mostrecomm3.head()

# %%
#matching positive words
y = 0
for z in range(0,len(sb_yelp_mostrecomm3)):
    
    for word in positive_words:
        if word == sb_yelp_mostrecomm3['word'][z]:
            sb_yelp_mostrecomm3['label'][z] ='positive'
            sb_yelp_mostrecomm3["Outcome"][z] = 1
            print ("this is running-positive" +str(y)+ word)
            print (sb_yelp_mostrecomm3['label'][z])
            y =y +1
            break;  

         
            
                
z = z + 1

# %%
#matching negative words
y = 0
for z in range(0,len(sb_yelp_mostrecomm3)):
    for negword in negative_words:        
        if negword == sb_yelp_mostrecomm3['word'][z]:
            sb_yelp_mostrecomm3['label'][z] ='negative'
            sb_yelp_mostrecomm3["Outcome"][z] = 0
            print ("this is running-negative"+str(y))
            print (sb_yelp_mostrecomm3['label'][z])
            y =y +1
            break;
#         elif sb_yelp_mostrecomm3['label'][z] =='':
#             sb_yelp_mostrecomm3['label'][z] ='neutral'            
#             sb_yelp_mostrecomm3['Outcome'][z] = 2
#             print ("this is running-neutral" +str(y))
#             print (sb_yelp_mostrecomm3['label'][z])
#             y =y +1
#             break; 
         
            
                
z = z + 1

# %%
#matching neutral words
y = 0
for z in range(0,len(sb_yelp_mostrecomm3)):
    if sb_yelp_mostrecomm3['label'][z] =='':
            sb_yelp_mostrecomm3['label'][z] ='neutral'            
            sb_yelp_mostrecomm3['Outcome'][z] = 2
            print ("this is running-neutral" +str(y))
            print (sb_yelp_mostrecomm3['label'][z])
            y =y +1
             
         
            
                
z = z + 1

# %%
negword

# %%
sb_yelp_mostrecomm3.head()
sb_yelp_mostrecomm3['label'].value_counts()


top10pos1_mr = sb_yelp_mostrecomm3[sb_yelp_mostrecomm3['label'].str.match('positive')][:10]
top10pos1_mr

top10neg1_mr = sb_yelp_mostrecomm3[sb_yelp_mostrecomm3['label'].str.match('negative')][:10]
#top10neg1_mr.reset_index(drop=True, inplace=True)# resets the index
#top10neg1_mr.index.name = 'Index'
top10neg1_mr

# %%
sb_yelp_mostrecomm3['label'].shape

# %%
# Labels for the sections of our pie chart
labels = ["Positive", "Negative", "Neutral"]

# The values of each section of the pie chart
sizes = [257,157,2677]

# The colors of each section of the pie chart
colors = ["lightskyblue", "red", "orange"]

# Tells matplotlib to seperate the "Python" section from the others
explode = (0.1, 0, 0)

# %%
# Creates the pie chart based upon the values above
# Automatically finds the percentages of each part of the pie chart
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
plt.title("Shanghai Joe's\n" + "overview", bbox={'facecolor':'0.8', 'pad':5})
plt.xlabel('User Reviews')
plt.ylabel('Words')
#plt.title('Interesting Graph\nCheck it out')
plt.legend()
plt.axis("equal")

# %%
frames2 = [top10pos1_mr, top10neg1_mr]

result_polar2 = pd.concat(frames2)
result_polar2.reset_index(drop=True, inplace=True)
result_polar2.index.name = 'Index'
result_polar2

# %%
plt.figure(figsize=(11,6))
colors = ['red' if c == 'negative' else 'blue' for c in result_polar2.label]
sns.barplot(y=result_polar2.word, x=result_polar2.word_freq, palette=colors)
plt.xlabel('Word Frequency', labelpad=10, fontsize=14)
plt.ylabel('Words', fontsize=14)
plt.title('TOP 10 Positive & Negative Words in Fish Cheeks Reviews', fontsize=15)
plt.tick_params(labelsize=14)
plt.xticks(rotation=15)
for  i, v in enumerate(result_polar2.word_freq):
    plt.text(v, i+0.3, str(v), fontweight='bold', color='green', fontsize=14)

# %%
sb_top_reviews1_db.head()

# %%
#**Hypothesis**: Can we predict the time from pour using the measurements of foam height and beer height?

# %%
#Variables/Columns TIME: Time from pour (seconds) 4-8 FOAM: Wet foam height (cm) 10-16 BEER: Beer height (cm) 18-24

# %%
# read csv into dataframe

reviews_ml = pd.read_csv('reviews_ml.csv', encoding='latin-1') # Yelp folder
reviews_ml = reviews_ml.dropna()

# %%
reviews_ml
# Out:
#    index    restaurant             label  \
# 0      1  Shanghai_joe     mostreviewed1
# 1      2        Eataly     mostreviewed2
# 2      3  ippudo_ramen     mostreviewed3
# 3      4   fish_cheeks  mostrecommended1
# 4      5      kotobuki  mostrecommended2
# 5      6        Au_zur  mostrecommended3
#
#                                              reviews  category
# 0  Made the trip to Chinatown to pick-up from Joe...   Seafood
# 1  I have been going to this place to eat at thei...   Italian
# 2  I love this style of Ramen - such a satisfying...     Ramen
# 3  We went here during Restaurant Week 2020. I ha...   Seafood
# 4  FOODCrispy rice spicy tuna app was delicious! ...  Japanese
# 5  Delicious flavored food; great concept to show...  Wine bar

# %%
# methods to clean up articles
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk import word_tokenize
import string
import re

stop_words_ = set(stopwords.words('english'))
wn = WordNetLemmatizer()
def accept_words(token):
    return token not in stop_words_ and token not in list(string.punctuation)
def clean_txt(text):
    clean_text = []
    text = re.sub("'", "",text)
    text=re.sub("[\d\W]+"," ",text)  
    clean_text = [ wn.lemmatize(word) for word in word_tokenize(text.lower()) if accept_words(word)]
    return " ".join(clean_text)

# additional features (subjectivity and polarity)
# however, have not used polarity since naive bayes can't take negative values
from textblob import TextBlob
#from sklearn.feature_extraction import DictVectorizer
import textstat

def hard_words(text):
    total_words = len(text.split())
    return textstat.difficult_words(text)/total_words
def subj_txt(text):
    return TextBlob(text).sentiment[1]
#def polarity_txt(text):
 #   return (TextBlob(text).sentiment[0] + 1)/2
def readability(text):
    return textstat.automated_readability_index(text)
def unique_words(text):
    return len(set(clean_txt(text).split()))/ len(text.split())



reviews_ml['subj'] = reviews_ml['reviews'].apply(subj_txt) # personal opinion, emotion or judgment whereas objective refers to factual information
#reviews_ml['pol'] = reviews_ml['reviews'].apply(polarity_txt)
reviews_ml['difficult_words'] = reviews_ml['reviews'].apply(hard_words) 
reviews_ml['readability'] = reviews_ml['reviews'].apply(readability)
reviews_ml['unique_words'] = reviews_ml['reviews'].apply(unique_words)

# %%
reviews_ml
# Out:
#    index    restaurant             label  \
# 0      1  Shanghai_joe     mostreviewed1
# 1      2        Eataly     mostreviewed2
# 2      3  ippudo_ramen     mostreviewed3
# 3      4   fish_cheeks  mostrecommended1
# 4      5      kotobuki  mostrecommended2
# 5      6        Au_zur  mostrecommended3
#
#                                              reviews  category      subj  \
# 0  Made the trip to Chinatown to pick-up from Joe...   Seafood  0.533423
# 1  I have been going to this place to eat at thei...   Italian  0.544122
# 2  I love this style of Ramen - such a satisfying...     Ramen  0.588851
# 3  We went here during Restaurant Week 2020. I ha...   Seafood  0.593936
# 4  FOODCrispy rice spicy tuna app was delicious! ...  Japanese  0.555991
# 5  Delicious flavored food; great concept to show...  Wine bar  0.597379
#
#    difficult_words  readability  unique_words
# 0         0.077656          8.0      0.213048
# 1         0.105055          8.9      0.268167
# 2         0.085482          7.0      0.229308
# 3         0.080390          7.1      0.221072
# 4         0.097561          7.5      0.266639
# 5         0.110359          7.0      0.281673

# %%
#Deep dive into Seafood Vs other protein Groups ??? - TBC

# %%
#running search through yelp and return the max results
data = []
count = 0
for offset in range(0, 1000, 50):
        params = {
            'limit': 50, 
            'location':'New York',
            'term': 'steak',
            'offset': offset
        }

        response = requests.get(url, headers=headers, params=params)
        if response.status_code == 200:
            data += response.json()['businesses']
            count = count + 1
        elif response.status_code == 400:
            print('400 Bad Request')
            break
data

# %%
#showing the results of the search in dataframe
df2 = pd.DataFrame(data)
df2

# %%
df2[['new_url2', 'new_url3']]=df2['url'].str.split('?', expand=True,n=2)

# %%
df2['new_url2'][2]

# %%
peter_luger = df2['new_url2'][0]
club_a = df2['new_url2'][1]
rocco = df2['new_url2'][2]

# %%
#Seabass
#url_top1
#url_top2
#url_top3
#url_rec1
#url_rec2
#url_rec3


start = 0
num_pages = 7
end = 20* num_pages
x = 1
reviews = []
quote_add = []

while (start < end):
    try:
        new_url = peter_luger + '?start=' + str(start)
        start +=20
        print (new_url)
        response = requests.get(new_url)
        soup = BeautifulSoup(response.text, "html.parser")
    #print(soup.prettify())
    #instructions = recipeSoup.find('div', class_='hidden').text
    #right_table4=soup.find_all('p', itemprop='description')
        quotes = soup.find_all('span', class_ = 'lemon--span__373c0__3997G raw__373c0__3rKqk')
        for quote in quotes:
            x = x+1
            print('Review:', x, '-------------')
            print(quote.text)
            quote_add.append(quote.text)
#-------------------------------------------------------------------newly added
#Makes all the letters lower in reviews
            review = quote.text.lower()
#expandContractions will put the dictionary made earlier to replace the contractions in the reviews
#Make sure to to run the cList dict cell or else there will be an error
            expandContractions(review)
#Cleaning the lemmas or words in reviews now will make it easier when we start predictive modeling
            words = word_tokenize(review)
            words = word_tokenize(review.replace('\n',' '))
            clean_words = [word.lower() for word in words if word not in set(string.punctuation)]
            characters_to_remove = ["''",'``','...']
            clean_words = [word for word in clean_words if word not in set(characters_to_remove)]
            english_stops = set(stopwords.words('english'))
            clean_words = [word for word in clean_words if word not in english_stops]
            wordnet_lemmatizer = WordNetLemmatizer()
            lemma_list = [wordnet_lemmatizer.lemmatize(word) for word in clean_words]
            #lemma_list = str.replace(right_table4.get_text(strip=True),". ",".")
            reviews.append(lemma_list)
    #reviews.add(a)
    except:
    #reviews.append(right_table4)
        time.sleep(5)
    #print("Reviews:", a,"\n")
        page = urllib.request.urlopen(url)
        soup = BeautifulSoup(page)

# %%
peter_l = pd.DataFrame(quote_add, columns=['reviews'])
# reviews_collect_cleaned = pd.DataFrame(np.array(reviews), columns=['review'])
# reviews_collect_cleaned.head()

# %%
#peter_l.to_csv (r'C:\Users\leroy\Desktop\reviews8.csv', index = True, header=True)

# %%
peter_l.head(5)

# %%
peter_l['subj'] = peter_l['reviews'].apply(subj_txt)
peter_l['pol'] = peter_l['reviews'].apply(polarity_txt)
peter_l['difficult_words'] = peter_l['reviews'].apply(hard_words)
peter_l['readability'] = peter_l['reviews'].apply(readability)
peter_l['unique_words'] = peter_l['reviews'].apply(unique_words)

# %%
peter_l = peter_l.drop([0, 1])

# %%
peter_l = peter_l.mean()

# %%
peter_l
